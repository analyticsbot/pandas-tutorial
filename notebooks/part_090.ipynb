# %% [markdown]
# #### Pandas Part 90: Styling DataFrames
#
# This notebook explores the styling capabilities in pandas, which allow you to format and style DataFrames for better visualization and presentation.

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ##### 1. Creating Sample DataFrames

# %%
# Create a sample DataFrame with numeric data
np.random.seed(42)
df_numeric = pd.DataFrame({
    'A': np.random.randn(5),
    'B': np.random.randn(5),
    'C': np.random.randn(5),
    'D': np.random.randn(5)
})

# Create a sample DataFrame with mixed data types
df_mixed = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 60000, 75000, 90000, 100000],
    'Department': ['HR', 'IT', 'Finance', 'Marketing', 'Operations']
})

# Display the DataFrames
print("Numeric DataFrame:")
display(df_numeric)

print("\nMixed DataFrame:")
display(df_mixed)
# Out:
# Numeric DataFrame:
#           A         B         C         D
# 0  0.496714 -0.234137 -0.463418 -0.562288
# 1 -0.138264  1.579213 -0.465730 -1.012831
# 2  0.647689  0.767435  0.241962  0.314247
# 3  1.523030 -0.469474 -1.913280 -0.908024
# 4 -0.234153  0.542560 -1.724918 -1.412304
# Mixed DataFrame:
#       Name  Age  Salary  Department
# 0    Alice   25   50000          HR
# 1      Bob   30   60000          IT
# 2  Charlie   35   75000     Finance
# 3    David   40   90000   Marketing
# 4      Eve   45  100000  Operations

# %% [markdown]
# ##### 2. Basic Styling
#
# The `.style` accessor returns a `Styler` object that can be used to style the DataFrame.

# %%
# Basic styling
styled = df_numeric.style
display(styled)
# Out:
# <style type="text/css">
# </style>
# <table id="T_746d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_746d7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_746d7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_746d7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_746d7_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_746d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_746d7_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_746d7_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_746d7_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_746d7_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_746d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_746d7_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_746d7_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_746d7_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_746d7_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_746d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_746d7_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_746d7_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_746d7_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_746d7_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_746d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_746d7_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_746d7_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_746d7_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_746d7_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_746d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_746d7_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_746d7_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_746d7_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_746d7_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 3. Highlighting Maximum and Minimum Values
#
# The `highlight_max()` and `highlight_min()` methods highlight the maximum and minimum values in the DataFrame.

# %%
# Highlight maximum values
styled_max = df_numeric.style.highlight_max(color='lightgreen')
display(styled_max)
# Out:
# <style type="text/css">
# #T_04c8f_row1_col1, #T_04c8f_row2_col2, #T_04c8f_row2_col3, #T_04c8f_row3_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_04c8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04c8f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_04c8f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_04c8f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_04c8f_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04c8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04c8f_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_04c8f_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_04c8f_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_04c8f_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_04c8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04c8f_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_04c8f_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_04c8f_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_04c8f_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_04c8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04c8f_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_04c8f_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_04c8f_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_04c8f_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_04c8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04c8f_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_04c8f_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_04c8f_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_04c8f_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_04c8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04c8f_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_04c8f_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_04c8f_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_04c8f_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highlight minimum values
styled_min = df_numeric.style.highlight_min(color='lightcoral')
display(styled_min)
# Out:
# <style type="text/css">
# #T_4f80b_row3_col1, #T_4f80b_row3_col2, #T_4f80b_row4_col0, #T_4f80b_row4_col3 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_4f80b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f80b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4f80b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_4f80b_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_4f80b_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f80b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f80b_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_4f80b_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_4f80b_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_4f80b_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_4f80b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f80b_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_4f80b_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_4f80b_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_4f80b_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_4f80b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f80b_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_4f80b_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_4f80b_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_4f80b_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_4f80b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f80b_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_4f80b_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_4f80b_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_4f80b_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_4f80b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f80b_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_4f80b_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_4f80b_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_4f80b_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highlight both maximum and minimum values
styled_both = df_numeric.style.highlight_max(color='lightgreen').highlight_min(color='lightcoral')
display(styled_both)
# Out:
# <style type="text/css">
# #T_e6edc_row1_col1, #T_e6edc_row2_col2, #T_e6edc_row2_col3, #T_e6edc_row3_col0 {
#   background-color: lightgreen;
# }
# #T_e6edc_row3_col1, #T_e6edc_row3_col2, #T_e6edc_row4_col0, #T_e6edc_row4_col3 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_e6edc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6edc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e6edc_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e6edc_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e6edc_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6edc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6edc_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_e6edc_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_e6edc_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_e6edc_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_e6edc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6edc_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_e6edc_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_e6edc_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_e6edc_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_e6edc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6edc_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_e6edc_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_e6edc_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_e6edc_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_e6edc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6edc_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_e6edc_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_e6edc_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_e6edc_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_e6edc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6edc_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_e6edc_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_e6edc_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_e6edc_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highlight max and min by row (axis=1)
styled_row = df_numeric.style.highlight_max(color='lightgreen', axis=1).highlight_min(color='lightcoral', axis=1)
display(styled_row)
# Out:
# <style type="text/css">
# #T_a1c4f_row0_col0, #T_a1c4f_row1_col1, #T_a1c4f_row2_col1, #T_a1c4f_row3_col0, #T_a1c4f_row4_col1 {
#   background-color: lightgreen;
# }
# #T_a1c4f_row0_col3, #T_a1c4f_row1_col3, #T_a1c4f_row2_col2, #T_a1c4f_row3_col2, #T_a1c4f_row4_col2 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_a1c4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1c4f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a1c4f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a1c4f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a1c4f_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1c4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1c4f_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_a1c4f_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_a1c4f_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_a1c4f_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_a1c4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1c4f_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_a1c4f_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_a1c4f_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_a1c4f_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_a1c4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1c4f_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_a1c4f_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_a1c4f_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_a1c4f_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_a1c4f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1c4f_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_a1c4f_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_a1c4f_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_a1c4f_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_a1c4f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1c4f_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_a1c4f_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_a1c4f_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_a1c4f_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 4. Formatting Values
#
# The `format()` method allows you to format the values in the DataFrame.

# %%
# Format all numeric values to 2 decimal places
styled_format = df_numeric.style.format("{:.2f}")
display(styled_format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_98089">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98089_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_98089_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_98089_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_98089_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98089_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98089_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_98089_row0_col1" class="data row0 col1" >-0.23</td>
#       <td id="T_98089_row0_col2" class="data row0 col2" >-0.46</td>
#       <td id="T_98089_row0_col3" class="data row0 col3" >-0.56</td>
#     </tr>
#     <tr>
#       <th id="T_98089_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98089_row1_col0" class="data row1 col0" >-0.14</td>
#       <td id="T_98089_row1_col1" class="data row1 col1" >1.58</td>
#       <td id="T_98089_row1_col2" class="data row1 col2" >-0.47</td>
#       <td id="T_98089_row1_col3" class="data row1 col3" >-1.01</td>
#     </tr>
#     <tr>
#       <th id="T_98089_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98089_row2_col0" class="data row2 col0" >0.65</td>
#       <td id="T_98089_row2_col1" class="data row2 col1" >0.77</td>
#       <td id="T_98089_row2_col2" class="data row2 col2" >0.24</td>
#       <td id="T_98089_row2_col3" class="data row2 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_98089_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98089_row3_col0" class="data row3 col0" >1.52</td>
#       <td id="T_98089_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_98089_row3_col2" class="data row3 col2" >-1.91</td>
#       <td id="T_98089_row3_col3" class="data row3 col3" >-0.91</td>
#     </tr>
#     <tr>
#       <th id="T_98089_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98089_row4_col0" class="data row4 col0" >-0.23</td>
#       <td id="T_98089_row4_col1" class="data row4 col1" >0.54</td>
#       <td id="T_98089_row4_col2" class="data row4 col2" >-1.72</td>
#       <td id="T_98089_row4_col3" class="data row4 col3" >-1.41</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Format different columns differently
styled_mixed_format = df_mixed.style.format({
    'Age': '{} years',
    'Salary': '${:,.2f}',
    'Department': lambda x: f'Dept: {x}'
})
display(styled_mixed_format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d7b3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7b3b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_d7b3b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_d7b3b_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_d7b3b_level0_col3" class="col_heading level0 col3" >Department</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7b3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7b3b_row0_col0" class="data row0 col0" >Alice</td>
#       <td id="T_d7b3b_row0_col1" class="data row0 col1" >25 years</td>
#       <td id="T_d7b3b_row0_col2" class="data row0 col2" >$50,000.00</td>
#       <td id="T_d7b3b_row0_col3" class="data row0 col3" >Dept: HR</td>
#     </tr>
#     <tr>
#       <th id="T_d7b3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7b3b_row1_col0" class="data row1 col0" >Bob</td>
#       <td id="T_d7b3b_row1_col1" class="data row1 col1" >30 years</td>
#       <td id="T_d7b3b_row1_col2" class="data row1 col2" >$60,000.00</td>
#       <td id="T_d7b3b_row1_col3" class="data row1 col3" >Dept: IT</td>
#     </tr>
#     <tr>
#       <th id="T_d7b3b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7b3b_row2_col0" class="data row2 col0" >Charlie</td>
#       <td id="T_d7b3b_row2_col1" class="data row2 col1" >35 years</td>
#       <td id="T_d7b3b_row2_col2" class="data row2 col2" >$75,000.00</td>
#       <td id="T_d7b3b_row2_col3" class="data row2 col3" >Dept: Finance</td>
#     </tr>
#     <tr>
#       <th id="T_d7b3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7b3b_row3_col0" class="data row3 col0" >David</td>
#       <td id="T_d7b3b_row3_col1" class="data row3 col1" >40 years</td>
#       <td id="T_d7b3b_row3_col2" class="data row3 col2" >$90,000.00</td>
#       <td id="T_d7b3b_row3_col3" class="data row3 col3" >Dept: Marketing</td>
#     </tr>
#     <tr>
#       <th id="T_d7b3b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7b3b_row4_col0" class="data row4 col0" >Eve</td>
#       <td id="T_d7b3b_row4_col1" class="data row4 col1" >45 years</td>
#       <td id="T_d7b3b_row4_col2" class="data row4 col2" >$100,000.00</td>
#       <td id="T_d7b3b_row4_col3" class="data row4 col3" >Dept: Operations</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 5. Applying Custom Styles with `applymap()` and `apply()`
#
# The `applymap()` method applies a function to each cell, while the `apply()` method applies a function to each row or column.

# %%
# Define a function to color cells based on their values
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property 'color: red' for negative
    values, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return f'color: {color}'

# Apply the function to each cell
styled_applymap = df_numeric.style.applymap(color_negative_red)
display(styled_applymap)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_93005/1430003876.py:12: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_applymap = df_numeric.style.applymap(color_negative_red)
# <style type="text/css">
# #T_6582a_row0_col0, #T_6582a_row1_col1, #T_6582a_row2_col0, #T_6582a_row2_col1, #T_6582a_row2_col2, #T_6582a_row2_col3, #T_6582a_row3_col0, #T_6582a_row4_col1 {
#   color: black;
# }
# #T_6582a_row0_col1, #T_6582a_row0_col2, #T_6582a_row0_col3, #T_6582a_row1_col0, #T_6582a_row1_col2, #T_6582a_row1_col3, #T_6582a_row3_col1, #T_6582a_row3_col2, #T_6582a_row3_col3, #T_6582a_row4_col0, #T_6582a_row4_col2, #T_6582a_row4_col3 {
#   color: red;
# }
# </style>
# <table id="T_6582a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6582a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6582a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_6582a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_6582a_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6582a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6582a_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_6582a_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_6582a_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_6582a_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_6582a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6582a_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_6582a_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_6582a_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_6582a_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_6582a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6582a_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_6582a_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_6582a_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_6582a_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_6582a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6582a_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_6582a_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_6582a_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_6582a_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_6582a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6582a_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_6582a_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_6582a_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_6582a_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Define a function to highlight the background of cells based on their values
def highlight_greaterthan(s, threshold):
    """
    Highlight values greater than threshold.
    """
    is_gt = s > threshold
    return ['background-color: yellow' if v else '' for v in is_gt]

# Apply the function to each column
styled_apply = df_numeric.style.apply(highlight_greaterthan, threshold=0.5, axis=0)
display(styled_apply)
# Out:
# <style type="text/css">
# #T_09c7e_row1_col1, #T_09c7e_row2_col0, #T_09c7e_row2_col1, #T_09c7e_row3_col0, #T_09c7e_row4_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_09c7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09c7e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_09c7e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_09c7e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_09c7e_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09c7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09c7e_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_09c7e_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_09c7e_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_09c7e_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_09c7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09c7e_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_09c7e_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_09c7e_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_09c7e_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_09c7e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09c7e_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_09c7e_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_09c7e_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_09c7e_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_09c7e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09c7e_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_09c7e_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_09c7e_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_09c7e_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_09c7e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09c7e_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_09c7e_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_09c7e_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_09c7e_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 6. Combining Multiple Styles
#
# You can chain multiple styling methods to combine different styles.

# %%
# Combine multiple styles
styled_combined = df_numeric.style\
    .format("{:.2f}")\
    .applymap(color_negative_red)\
    .highlight_max(color='lightgreen')\
    .highlight_min(color='lightcoral')
    
display(styled_combined)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_93005/4189852918.py:4: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_negative_red)\
# <style type="text/css">
# #T_8263c_row0_col0, #T_8263c_row2_col0, #T_8263c_row2_col1, #T_8263c_row4_col1 {
#   color: black;
# }
# #T_8263c_row0_col1, #T_8263c_row0_col2, #T_8263c_row0_col3, #T_8263c_row1_col0, #T_8263c_row1_col2, #T_8263c_row1_col3, #T_8263c_row3_col3, #T_8263c_row4_col2 {
#   color: red;
# }
# #T_8263c_row1_col1, #T_8263c_row2_col2, #T_8263c_row2_col3, #T_8263c_row3_col0 {
#   color: black;
#   background-color: lightgreen;
# }
# #T_8263c_row3_col1, #T_8263c_row3_col2, #T_8263c_row4_col0, #T_8263c_row4_col3 {
#   color: red;
#   background-color: lightcoral;
# }
# </style>
# <table id="T_8263c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8263c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8263c_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8263c_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8263c_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8263c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8263c_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_8263c_row0_col1" class="data row0 col1" >-0.23</td>
#       <td id="T_8263c_row0_col2" class="data row0 col2" >-0.46</td>
#       <td id="T_8263c_row0_col3" class="data row0 col3" >-0.56</td>
#     </tr>
#     <tr>
#       <th id="T_8263c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8263c_row1_col0" class="data row1 col0" >-0.14</td>
#       <td id="T_8263c_row1_col1" class="data row1 col1" >1.58</td>
#       <td id="T_8263c_row1_col2" class="data row1 col2" >-0.47</td>
#       <td id="T_8263c_row1_col3" class="data row1 col3" >-1.01</td>
#     </tr>
#     <tr>
#       <th id="T_8263c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8263c_row2_col0" class="data row2 col0" >0.65</td>
#       <td id="T_8263c_row2_col1" class="data row2 col1" >0.77</td>
#       <td id="T_8263c_row2_col2" class="data row2 col2" >0.24</td>
#       <td id="T_8263c_row2_col3" class="data row2 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_8263c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8263c_row3_col0" class="data row3 col0" >1.52</td>
#       <td id="T_8263c_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_8263c_row3_col2" class="data row3 col2" >-1.91</td>
#       <td id="T_8263c_row3_col3" class="data row3 col3" >-0.91</td>
#     </tr>
#     <tr>
#       <th id="T_8263c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8263c_row4_col0" class="data row4 col0" >-0.23</td>
#       <td id="T_8263c_row4_col1" class="data row4 col1" >0.54</td>
#       <td id="T_8263c_row4_col2" class="data row4 col2" >-1.72</td>
#       <td id="T_8263c_row4_col3" class="data row4 col3" >-1.41</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 7. Using `background_gradient()` for Heatmaps
#
# The `background_gradient()` method applies a color gradient to the background of cells based on their values.

# %%
# Create a heatmap using background_gradient
styled_heatmap = df_numeric.style.background_gradient(cmap='viridis')
display(styled_heatmap)
# Out:
# <style type="text/css">
# #T_042bf_row0_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_042bf_row0_col1 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_042bf_row0_col2 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_042bf_row0_col3, #T_042bf_row4_col1 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_042bf_row1_col0 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_042bf_row1_col1, #T_042bf_row2_col2, #T_042bf_row2_col3, #T_042bf_row3_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_042bf_row1_col2 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_042bf_row1_col3 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_042bf_row2_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_042bf_row2_col1 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_042bf_row3_col1, #T_042bf_row3_col2, #T_042bf_row4_col0, #T_042bf_row4_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_042bf_row3_col3 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_042bf_row4_col2 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_042bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_042bf_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_042bf_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_042bf_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_042bf_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_042bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_042bf_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_042bf_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_042bf_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_042bf_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_042bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_042bf_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_042bf_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_042bf_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_042bf_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_042bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_042bf_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_042bf_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_042bf_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_042bf_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_042bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_042bf_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_042bf_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_042bf_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_042bf_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_042bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_042bf_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_042bf_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_042bf_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_042bf_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Apply background_gradient to specific columns
styled_heatmap_subset = df_numeric.style.background_gradient(cmap='viridis', subset=['A', 'B'])
display(styled_heatmap_subset)
# Out:
# <style type="text/css">
# #T_074ef_row0_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_074ef_row0_col1 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_074ef_row1_col0 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_074ef_row1_col1, #T_074ef_row3_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_074ef_row2_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_074ef_row2_col1 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_074ef_row3_col1, #T_074ef_row4_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_074ef_row4_col1 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_074ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_074ef_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_074ef_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_074ef_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_074ef_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_074ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_074ef_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_074ef_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_074ef_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_074ef_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_074ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_074ef_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_074ef_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_074ef_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_074ef_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_074ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_074ef_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_074ef_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_074ef_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_074ef_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_074ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_074ef_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_074ef_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_074ef_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_074ef_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_074ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_074ef_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_074ef_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_074ef_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_074ef_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 8. Using `bar()` for Bar Charts
#
# The `bar()` method creates a bar chart within the cells of the DataFrame.

# %%
# Create a bar chart
styled_bar = df_numeric.style.bar(color=['lightblue', 'lightgreen'], align='mid')
display(styled_bar)
# Out:
# <style type="text/css">
# #T_e07f8_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.3%, lightgreen 13.3%, lightgreen 41.6%, transparent 41.6%);
# }
# #T_e07f8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 11.5%, lightblue 11.5%, lightblue 22.9%, transparent 22.9%);
# }
# #T_e07f8_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 67.3%, lightblue 67.3%, lightblue 88.8%, transparent 88.8%);
# }
# #T_e07f8_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.2%, lightblue 49.2%, lightblue 81.8%, transparent 81.8%);
# }
# #T_e07f8_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.5%, lightblue 5.5%, lightblue 13.3%, transparent 13.3%);
# }
# #T_e07f8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.9%, lightgreen 22.9%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_e07f8_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 67.2%, lightblue 67.2%, lightblue 88.8%, transparent 88.8%);
# }
# #T_e07f8_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.1%, lightblue 23.1%, lightblue 81.8%, transparent 81.8%);
# }
# #T_e07f8_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.3%, lightgreen 13.3%, lightgreen 50.2%, transparent 50.2%);
# }
# #T_e07f8_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.9%, lightgreen 22.9%, lightgreen 60.4%, transparent 60.4%);
# }
# #T_e07f8_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 88.8%, lightgreen 88.8%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_e07f8_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 81.8%, lightgreen 81.8%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_e07f8_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.3%, lightgreen 13.3%, lightgreen 100.0%, transparent 100.0%);
# }
# #T_e07f8_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 22.9%, transparent 22.9%);
# }
# #T_e07f8_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 88.8%, transparent 88.8%);
# }
# #T_e07f8_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.2%, lightblue 29.2%, lightblue 81.8%, transparent 81.8%);
# }
# #T_e07f8_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 13.3%, transparent 13.3%);
# }
# #T_e07f8_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.9%, lightgreen 22.9%, lightgreen 49.4%, transparent 49.4%);
# }
# #T_e07f8_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.7%, lightblue 8.7%, lightblue 88.8%, transparent 88.8%);
# }
# #T_e07f8_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 81.8%, transparent 81.8%);
# }
# </style>
# <table id="T_e07f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e07f8_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e07f8_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e07f8_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e07f8_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e07f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e07f8_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_e07f8_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_e07f8_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_e07f8_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_e07f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e07f8_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_e07f8_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_e07f8_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_e07f8_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_e07f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e07f8_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_e07f8_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_e07f8_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_e07f8_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_e07f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e07f8_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_e07f8_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_e07f8_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_e07f8_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_e07f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e07f8_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_e07f8_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_e07f8_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_e07f8_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Apply bar chart to specific columns
styled_bar_subset = df_numeric.style.bar(subset=['C', 'D'], color='lightcoral', align='zero')
display(styled_bar_subset)
# Out:
# <style type="text/css">
# #T_bb466_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.9%, lightcoral 37.9%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.1%, lightcoral 30.1%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.8%, lightcoral 37.8%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.1%, lightcoral 14.1%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightcoral 50.0%, lightcoral 56.3%, transparent 56.3%);
# }
# #T_bb466_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightcoral 50.0%, lightcoral 61.1%, transparent 61.1%);
# }
# #T_bb466_row3_col2, #T_bb466_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.9%, lightcoral 17.9%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_bb466_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.9%, lightcoral 4.9%, lightcoral 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_bb466">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb466_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_bb466_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_bb466_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_bb466_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb466_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb466_row0_col0" class="data row0 col0" >0.496714</td>
#       <td id="T_bb466_row0_col1" class="data row0 col1" >-0.234137</td>
#       <td id="T_bb466_row0_col2" class="data row0 col2" >-0.463418</td>
#       <td id="T_bb466_row0_col3" class="data row0 col3" >-0.562288</td>
#     </tr>
#     <tr>
#       <th id="T_bb466_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb466_row1_col0" class="data row1 col0" >-0.138264</td>
#       <td id="T_bb466_row1_col1" class="data row1 col1" >1.579213</td>
#       <td id="T_bb466_row1_col2" class="data row1 col2" >-0.465730</td>
#       <td id="T_bb466_row1_col3" class="data row1 col3" >-1.012831</td>
#     </tr>
#     <tr>
#       <th id="T_bb466_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb466_row2_col0" class="data row2 col0" >0.647689</td>
#       <td id="T_bb466_row2_col1" class="data row2 col1" >0.767435</td>
#       <td id="T_bb466_row2_col2" class="data row2 col2" >0.241962</td>
#       <td id="T_bb466_row2_col3" class="data row2 col3" >0.314247</td>
#     </tr>
#     <tr>
#       <th id="T_bb466_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb466_row3_col0" class="data row3 col0" >1.523030</td>
#       <td id="T_bb466_row3_col1" class="data row3 col1" >-0.469474</td>
#       <td id="T_bb466_row3_col2" class="data row3 col2" >-1.913280</td>
#       <td id="T_bb466_row3_col3" class="data row3 col3" >-0.908024</td>
#     </tr>
#     <tr>
#       <th id="T_bb466_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb466_row4_col0" class="data row4 col0" >-0.234153</td>
#       <td id="T_bb466_row4_col1" class="data row4 col1" >0.542560</td>
#       <td id="T_bb466_row4_col2" class="data row4 col2" >-1.724918</td>
#       <td id="T_bb466_row4_col3" class="data row4 col3" >-1.412304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 9. Hiding Index and Columns
#
# The `hide_index()` and `hide_columns()` methods allow you to hide the index and specific columns.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame
df_numeric = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
print("Original DataFrame:")
print(df_numeric)

# Method 1: Use style.hide() with axis parameter (for newer pandas versions)
try:
    styled_hide_index = df_numeric.style.hide(axis='index')
    print("\nMethod 1: Using style.hide(axis='index'):")
    display(styled_hide_index)
except AttributeError:
    print("\nMethod 1 not available in this pandas version")

# Method 2: Alternative approach - create a copy with reset_index and drop=True
df_no_index = df_numeric.reset_index(drop=True)
styled_no_index = df_no_index.style
print("\nMethod 2: Using reset_index(drop=True):")
display(styled_no_index)

# Method 3: Set index names to empty strings (visual effect only)
df_empty_index = df_numeric.copy()
df_empty_index.index.name = ''
styled_empty_index = df_empty_index.style
print("\nMethod 3: Setting index name to empty string:")
display(styled_empty_index)
# Out:
# Original DataFrame:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500
#
# Method 1: Using style.hide(axis='index'):
# <style type="text/css">
# </style>
# <table id="T_0792b">
#   <thead>
#     <tr>
#       <th id="T_0792b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0792b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_0792b_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0792b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0792b_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_0792b_row0_col2" class="data row0 col2" >100</td>
#     </tr>
#     <tr>
#       <td id="T_0792b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0792b_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_0792b_row1_col2" class="data row1 col2" >200</td>
#     </tr>
#     <tr>
#       <td id="T_0792b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0792b_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_0792b_row2_col2" class="data row2 col2" >300</td>
#     </tr>
#     <tr>
#       <td id="T_0792b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0792b_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_0792b_row3_col2" class="data row3 col2" >400</td>
#     </tr>
#     <tr>
#       <td id="T_0792b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_0792b_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_0792b_row4_col2" class="data row4 col2" >500</td>
#     </tr>
#   </tbody>
# </table>
# Method 2: Using reset_index(drop=True):
# <style type="text/css">
# </style>
# <table id="T_8623a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8623a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8623a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8623a_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8623a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8623a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8623a_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_8623a_row0_col2" class="data row0 col2" >100</td>
#     </tr>
#     <tr>
#       <th id="T_8623a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8623a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_8623a_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_8623a_row1_col2" class="data row1 col2" >200</td>
#     </tr>
#     <tr>
#       <th id="T_8623a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8623a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_8623a_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_8623a_row2_col2" class="data row2 col2" >300</td>
#     </tr>
#     <tr>
#       <th id="T_8623a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8623a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8623a_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_8623a_row3_col2" class="data row3 col2" >400</td>
#     </tr>
#     <tr>
#       <th id="T_8623a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8623a_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_8623a_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_8623a_row4_col2" class="data row4 col2" >500</td>
#     </tr>
#   </tbody>
# </table>
# Method 3: Setting index name to empty string:
# <style type="text/css">
# </style>
# <table id="T_f8bb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8bb0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f8bb0_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_f8bb0_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8bb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8bb0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f8bb0_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_f8bb0_row0_col2" class="data row0 col2" >100</td>
#     </tr>
#     <tr>
#       <th id="T_f8bb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8bb0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f8bb0_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_f8bb0_row1_col2" class="data row1 col2" >200</td>
#     </tr>
#     <tr>
#       <th id="T_f8bb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8bb0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f8bb0_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_f8bb0_row2_col2" class="data row2 col2" >300</td>
#     </tr>
#     <tr>
#       <th id="T_f8bb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8bb0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f8bb0_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_f8bb0_row3_col2" class="data row3 col2" >400</td>
#     </tr>
#     <tr>
#       <th id="T_f8bb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8bb0_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f8bb0_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_f8bb0_row4_col2" class="data row4 col2" >500</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame
df_numeric = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500],
    'D': [1000, 2000, 3000, 4000, 5000]
})
print("Original DataFrame:")
print(df_numeric)

# Method 1: Use style.hide() with subset parameter (for newer pandas versions)
try:
    styled_hide_columns = df_numeric.style.hide(subset=None, axis='columns', level=None, names=['B', 'D'])
    print("\nMethod 1: Using style.hide() with columns:")
    display(styled_hide_columns)
except (AttributeError, TypeError) as e:
    print(f"\nMethod 1 not available in this pandas version: {e}")

# Method 2: Alternative approach - create a copy with only the columns you want to display
df_selected_columns = df_numeric[['A', 'C']]  # Exclude 'B' and 'D'
styled_selected = df_selected_columns.style
print("\nMethod 2: Using DataFrame selection to exclude columns:")
display(styled_selected)

# Method 3: For display purposes, you can use a function to format unwanted columns as empty
def hide_columns(df, columns_to_hide):
    # Create a copy to avoid modifying the original
    df_copy = df.copy()
    # Replace values in columns to hide with empty strings
    for col in columns_to_hide:
        if col in df_copy.columns:
            df_copy[col] = ''
    return df_copy

df_formatted = hide_columns(df_numeric, ['B', 'D'])
styled_formatted = df_formatted.style
print("\nMethod 3: Replacing values in columns to hide with empty strings:")
display(styled_formatted)
# Out:
# Original DataFrame:
#    A   B    C     D
# 0  1  10  100  1000
# 1  2  20  200  2000
# 2  3  30  300  3000
# 3  4  40  400  4000
# 4  5  50  500  5000
#
# Method 1: Using style.hide() with columns:
# <style type="text/css">
# </style>
# <table id="T_ec6d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec6d5_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ec6d5_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ec6d5_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ec6d5_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec6d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec6d5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ec6d5_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_ec6d5_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_ec6d5_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_ec6d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec6d5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ec6d5_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_ec6d5_row1_col2" class="data row1 col2" >200</td>
#       <td id="T_ec6d5_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_ec6d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec6d5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ec6d5_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_ec6d5_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_ec6d5_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <th id="T_ec6d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec6d5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ec6d5_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_ec6d5_row3_col2" class="data row3 col2" >400</td>
#       <td id="T_ec6d5_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <th id="T_ec6d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec6d5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ec6d5_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_ec6d5_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_ec6d5_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#   </tbody>
# </table>
# Method 2: Using DataFrame selection to exclude columns:
# <style type="text/css">
# </style>
# <table id="T_55f0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55f0f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_55f0f_level0_col1" class="col_heading level0 col1" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55f0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55f0f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_55f0f_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_55f0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55f0f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_55f0f_row1_col1" class="data row1 col1" >200</td>
#     </tr>
#     <tr>
#       <th id="T_55f0f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55f0f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_55f0f_row2_col1" class="data row2 col1" >300</td>
#     </tr>
#     <tr>
#       <th id="T_55f0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55f0f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_55f0f_row3_col1" class="data row3 col1" >400</td>
#     </tr>
#     <tr>
#       <th id="T_55f0f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55f0f_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_55f0f_row4_col1" class="data row4 col1" >500</td>
#     </tr>
#   </tbody>
# </table>
# Method 3: Replacing values in columns to hide with empty strings:
# <style type="text/css">
# </style>
# <table id="T_45550">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45550_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_45550_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_45550_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_45550_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45550_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45550_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_45550_row0_col1" class="data row0 col1" ></td>
#       <td id="T_45550_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_45550_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_45550_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45550_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_45550_row1_col1" class="data row1 col1" ></td>
#       <td id="T_45550_row1_col2" class="data row1 col2" >200</td>
#       <td id="T_45550_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_45550_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45550_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_45550_row2_col1" class="data row2 col1" ></td>
#       <td id="T_45550_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_45550_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_45550_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45550_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_45550_row3_col1" class="data row3 col1" ></td>
#       <td id="T_45550_row3_col2" class="data row3 col2" >400</td>
#       <td id="T_45550_row3_col3" class="data row3 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_45550_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45550_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_45550_row4_col1" class="data row4 col1" ></td>
#       <td id="T_45550_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_45550_row4_col3" class="data row4 col3" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 10. Setting Table Styles
#
# The `set_table_styles()` method allows you to set CSS styles for the entire table.

# %%
# Set table styles
table_styles = [
    {'selector': 'th', 'props': [('background-color', 'lightblue'), ('color', 'black'), ('font-weight', 'bold')]},
    {'selector': 'td', 'props': [('padding', '5px')]},
    {'selector': 'tr:hover', 'props': [('background-color', 'lightyellow')]}
]

styled_table = df_numeric.style.set_table_styles(table_styles)
display(styled_table)
# Out:
# <style type="text/css">
# #T_936af th {
#   background-color: lightblue;
#   color: black;
#   font-weight: bold;
# }
# #T_936af td {
#   padding: 5px;
# }
# #T_936af tr:hover {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_936af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_936af_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_936af_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_936af_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_936af_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_936af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_936af_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_936af_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_936af_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_936af_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_936af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_936af_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_936af_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_936af_row1_col2" class="data row1 col2" >200</td>
#       <td id="T_936af_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_936af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_936af_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_936af_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_936af_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_936af_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <th id="T_936af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_936af_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_936af_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_936af_row3_col2" class="data row3 col2" >400</td>
#       <td id="T_936af_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <th id="T_936af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_936af_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_936af_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_936af_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_936af_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 11. Setting Properties for Specific Cells
#
# The `set_properties()` method allows you to set CSS properties for specific cells.

# %%
# Set properties for specific cells
styled_properties = df_numeric.style.set_properties(**{'background-color': 'lightgray', 'color': 'black', 'border': '1px solid black'})
display(styled_properties)
# Out:
# <style type="text/css">
# #T_ac61e_row0_col0, #T_ac61e_row0_col1, #T_ac61e_row0_col2, #T_ac61e_row0_col3, #T_ac61e_row1_col0, #T_ac61e_row1_col1, #T_ac61e_row1_col2, #T_ac61e_row1_col3, #T_ac61e_row2_col0, #T_ac61e_row2_col1, #T_ac61e_row2_col2, #T_ac61e_row2_col3, #T_ac61e_row3_col0, #T_ac61e_row3_col1, #T_ac61e_row3_col2, #T_ac61e_row3_col3, #T_ac61e_row4_col0, #T_ac61e_row4_col1, #T_ac61e_row4_col2, #T_ac61e_row4_col3 {
#   background-color: lightgray;
#   color: black;
#   border: 1px solid black;
# }
# </style>
# <table id="T_ac61e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac61e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ac61e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ac61e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ac61e_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac61e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac61e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ac61e_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_ac61e_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_ac61e_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_ac61e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac61e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ac61e_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_ac61e_row1_col2" class="data row1 col2" >200</td>
#       <td id="T_ac61e_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_ac61e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac61e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ac61e_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_ac61e_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_ac61e_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <th id="T_ac61e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac61e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ac61e_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_ac61e_row3_col2" class="data row3 col2" >400</td>
#       <td id="T_ac61e_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <th id="T_ac61e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac61e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ac61e_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_ac61e_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_ac61e_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set properties for specific columns
styled_properties_subset = df_numeric.style.set_properties(subset=['A', 'C'], **{'background-color': 'lightblue'})
display(styled_properties_subset)
# Out:
# <style type="text/css">
# #T_42be7_row0_col0, #T_42be7_row0_col2, #T_42be7_row1_col0, #T_42be7_row1_col2, #T_42be7_row2_col0, #T_42be7_row2_col2, #T_42be7_row3_col0, #T_42be7_row3_col2, #T_42be7_row4_col0, #T_42be7_row4_col2 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_42be7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42be7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_42be7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_42be7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_42be7_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42be7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42be7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_42be7_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_42be7_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_42be7_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_42be7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42be7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_42be7_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_42be7_row1_col2" class="data row1 col2" >200</td>
#       <td id="T_42be7_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_42be7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42be7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_42be7_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_42be7_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_42be7_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <th id="T_42be7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42be7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_42be7_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_42be7_row3_col2" class="data row3 col2" >400</td>
#       <td id="T_42be7_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <th id="T_42be7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42be7_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_42be7_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_42be7_row4_col2" class="data row4 col2" >500</td>
#       <td id="T_42be7_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 12. Using `highlight_null()` to Highlight Missing Values
#
# The `highlight_null()` method highlights missing values in the DataFrame.

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with missing values
df_numeric = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

df_missing = df_numeric.copy()
df_missing.iloc[0, 0] = np.nan
df_missing.iloc[1, 2] = np.nan
df_missing.iloc[3, 1] = np.nan
print("DataFrame with missing values:")
print(df_missing)

# Method 1: Use highlight_null without parameters
try:
    styled_missing = df_missing.style.highlight_null()
    print("\nMethod 1: Using highlight_null() without parameters:")
    display(styled_missing)
except TypeError as e:
    print(f"\nMethod 1 error: {e}")

# Method 2: Use a custom styling function
def highlight_nulls(x):
    is_null = pd.isna(x)
    return ['background-color: red' if v else '' for v in is_null]

try:
    styled_custom = df_missing.style.apply(highlight_nulls, axis=1)
    print("\nMethod 2: Using custom styling function:")
    display(styled_custom)
except Exception as e:
    print(f"\nMethod 2 error: {e}")

# Method 3: Use applymap for cell-by-cell styling
def highlight_null_cells(val):
    if pd.isna(val):
        return 'background-color: red'
    return ''

try:
    styled_applymap = df_missing.style.applymap(highlight_null_cells)
    print("\nMethod 3: Using applymap for cell-by-cell styling:")
    display(styled_applymap)
except Exception as e:
    print(f"\nMethod 3 error: {e}")
# Out:
# DataFrame with missing values:
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0  20.0    NaN
# 2  3.0  30.0  300.0
# 3  4.0   NaN  400.0
# 4  5.0  50.0  500.0
#
# Method 1: Using highlight_null() without parameters:
# <style type="text/css">
# #T_7d96e_row0_col0, #T_7d96e_row1_col2, #T_7d96e_row3_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_7d96e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d96e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7d96e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7d96e_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d96e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d96e_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_7d96e_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_7d96e_row0_col2" class="data row0 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7d96e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d96e_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_7d96e_row1_col1" class="data row1 col1" >20.000000</td>
#       <td id="T_7d96e_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7d96e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d96e_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_7d96e_row2_col1" class="data row2 col1" >30.000000</td>
#       <td id="T_7d96e_row2_col2" class="data row2 col2" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7d96e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d96e_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_7d96e_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_7d96e_row3_col2" class="data row3 col2" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7d96e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d96e_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_7d96e_row4_col1" class="data row4 col1" >50.000000</td>
#       <td id="T_7d96e_row4_col2" class="data row4 col2" >500.000000</td>
#     </tr>
#   </tbody>
# </table>
# Method 2: Using custom styling function:
# <style type="text/css">
# #T_3dfea_row0_col0, #T_3dfea_row1_col2, #T_3dfea_row3_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_3dfea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dfea_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3dfea_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_3dfea_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dfea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dfea_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_3dfea_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_3dfea_row0_col2" class="data row0 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3dfea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3dfea_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_3dfea_row1_col1" class="data row1 col1" >20.000000</td>
#       <td id="T_3dfea_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3dfea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3dfea_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_3dfea_row2_col1" class="data row2 col1" >30.000000</td>
#       <td id="T_3dfea_row2_col2" class="data row2 col2" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3dfea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3dfea_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_3dfea_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_3dfea_row3_col2" class="data row3 col2" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3dfea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3dfea_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_3dfea_row4_col1" class="data row4 col1" >50.000000</td>
#       <td id="T_3dfea_row4_col2" class="data row4 col2" >500.000000</td>
#     </tr>
#   </tbody>
# </table>
# Method 3: Using applymap for cell-by-cell styling:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_93005/2130145940.py:45: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_applymap = df_missing.style.applymap(highlight_null_cells)
# <style type="text/css">
# #T_a61c7_row0_col0, #T_a61c7_row1_col2, #T_a61c7_row3_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_a61c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a61c7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a61c7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a61c7_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a61c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a61c7_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a61c7_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_a61c7_row0_col2" class="data row0 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a61c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a61c7_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_a61c7_row1_col1" class="data row1 col1" >20.000000</td>
#       <td id="T_a61c7_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a61c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a61c7_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_a61c7_row2_col1" class="data row2 col1" >30.000000</td>
#       <td id="T_a61c7_row2_col2" class="data row2 col2" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a61c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a61c7_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_a61c7_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_a61c7_row3_col2" class="data row3 col2" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a61c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a61c7_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_a61c7_row4_col1" class="data row4 col1" >50.000000</td>
#       <td id="T_a61c7_row4_col2" class="data row4 col2" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 13. Exporting Styled DataFrames
#
# You can export styled DataFrames to HTML or Excel.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame
df_numeric = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

# Apply some styling
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return f'color: {color}'

# Create a styled DataFrame
styled_combined = df_numeric.style.applymap(color_negative_red)

# Method 1: Use to_html() method (available in most pandas versions)
try:
    html = styled_combined.to_html()
    print("Method 1: Using to_html()")
    print("HTML output (first 500 characters):")
    print(html[:500])
except AttributeError as e:
    print(f"Method 1 error: {e}")

# Method 2: Alternative approach using DataFrame's to_html
try:
    html_basic = df_numeric.to_html()
    print("\nMethod 2: Using DataFrame's to_html() (without styling)")
    print("HTML output (first 500 characters):")
    print(html_basic[:500])
except Exception as e:
    print(f"Method 2 error: {e}")

# Method 3: Try _repr_html_ method which is used for notebook display
try:
    html_repr = styled_combined._repr_html_()
    print("\nMethod 3: Using _repr_html_()")
    print("HTML output (first 500 characters):")
    print(html_repr[:500])
except AttributeError as e:
    print(f"Method 3 error: {e}")

# Save to file (if any method worked)
try:
    if 'html' in locals():
        with open('styled_dataframe.html', 'w') as f:
            f.write(html)
        print("\nSaved styled HTML to 'styled_dataframe.html'")
    elif 'html_repr' in locals():
        with open('styled_dataframe.html', 'w') as f:
            f.write(html_repr)
        print("\nSaved styled HTML to 'styled_dataframe.html'")
    else:
        with open('basic_dataframe.html', 'w') as f:
            f.write(html_basic)
        print("\nSaved basic HTML to 'basic_dataframe.html'")
except Exception as e:
    print(f"Error saving to file: {e}")
# Out:
# Method 1: Using to_html()
# HTML output (first 500 characters):
# <style type="text/css">
# #T_41293_row0_col0, #T_41293_row0_col1, #T_41293_row0_col2, #T_41293_row1_col0, #T_41293_row1_col1, #T_41293_row1_col2, #T_41293_row2_col0, #T_41293_row2_col1, #T_41293_row2_col2, #T_41293_row3_col0, #T_41293_row3_col1, #T_41293_row3_col2, #T_41293_row4_col0, #T_41293_row4_col1, #T_41293_row4_col2 {
#   color: black;
# }
# </style>
# <table id="T_41293">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41293_level0_col0" class="col_heading level0 col
#
# Method 2: Using DataFrame's to_html() (without styling)
# HTML output (first 500 characters):
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>20</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>30</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#
#
# Method 3: Using _repr_html_()
# HTML output (first 500 characters):
# <style type="text/css">
# #T_41293_row0_col0, #T_41293_row0_col1, #T_41293_row0_col2, #T_41293_row1_col0, #T_41293_row1_col1, #T_41293_row1_col2, #T_41293_row2_col0, #T_41293_row2_col1, #T_41293_row2_col2, #T_41293_row3_col0, #T_41293_row3_col1, #T_41293_row3_col2, #T_41293_row4_col0, #T_41293_row4_col1, #T_41293_row4_col2 {
#   color: black;
# }
# </style>
# <table id="T_41293">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41293_level0_col0" class="col_heading level0 col
#
# Saved styled HTML to 'styled_dataframe.html'
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_93005/2868036475.py:17: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_combined = df_numeric.style.applymap(color_negative_red)

# %%
# Export to Excel (commented out to avoid creating files)
# styled_combined.to_excel('styled_dataframe.xlsx', engine='openpyxl')

# %% [markdown]
# ##### 14. Creating a Comprehensive Styled Dashboard
#
# Let's create a comprehensive styled dashboard by combining multiple styling techniques.

# %%
# Create a sample sales data DataFrame
np.random.seed(42)
sales_data = pd.DataFrame({
    'Product': ['Product A', 'Product B', 'Product C', 'Product D', 'Product E'],
    'Q1_Sales': np.random.randint(100, 1000, 5),
    'Q2_Sales': np.random.randint(100, 1000, 5),
    'Q3_Sales': np.random.randint(100, 1000, 5),
    'Q4_Sales': np.random.randint(100, 1000, 5),
})

# Calculate total sales
sales_data['Total_Sales'] = sales_data[['Q1_Sales', 'Q2_Sales', 'Q3_Sales', 'Q4_Sales']].sum(axis=1)

# Create a styled dashboard
dashboard = sales_data.style\
    .format({'Q1_Sales': '${:,.0f}', 'Q2_Sales': '${:,.0f}', 'Q3_Sales': '${:,.0f}', 'Q4_Sales': '${:,.0f}', 'Total_Sales': '${:,.0f}'})\
    .background_gradient(cmap='Blues', subset=['Total_Sales'])\
    .bar(subset=['Q1_Sales', 'Q2_Sales', 'Q3_Sales', 'Q4_Sales'], color='lightblue', align='mid')\
    .highlight_max(subset=['Q1_Sales', 'Q2_Sales', 'Q3_Sales', 'Q4_Sales'], color='lightgreen')\
    .highlight_min(subset=['Q1_Sales', 'Q2_Sales', 'Q3_Sales', 'Q4_Sales'], color='lightcoral')\
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#4CAF50'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'td', 'props': [('padding', '5px')]},
        {'selector': 'caption', 'props': [('caption-side', 'top'), ('font-size', '1.5em'), ('font-weight', 'bold')]}
    ])\
    .set_caption('Sales Dashboard - Quarterly Performance')

display(dashboard)
# Out:
# <style type="text/css">
# #T_37b01 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
# }
# #T_37b01 td {
#   padding: 5px;
# }
# #T_37b01 caption {
#   caption-side: top;
#   font-size: 1.5em;
#   font-weight: bold;
# }
# #T_37b01_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.0%, transparent 21.0%);
#   background-color: lightcoral;
# }
# #T_37b01_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.4%, transparent 21.4%);
# }
# #T_37b01_row0_col3, #T_37b01_row1_col2, #T_37b01_row2_col1, #T_37b01_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
#   background-color: lightgreen;
# }
# #T_37b01_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 48.6%, transparent 48.6%);
# }
# #T_37b01_row0_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_37b01_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 55.7%, transparent 55.7%);
# }
# #T_37b01_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 55.5%, transparent 55.5%);
# }
# #T_37b01_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 20.5%, transparent 20.5%);
#   background-color: lightcoral;
# }
# #T_37b01_row1_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_37b01_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 15.0%, transparent 15.0%);
#   background-color: lightcoral;
# }
# #T_37b01_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 76.0%, transparent 76.0%);
# }
# #T_37b01_row2_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_37b01_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 38.5%, transparent 38.5%);
# }
# #T_37b01_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 89.2%, transparent 89.2%);
# }
# #T_37b01_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 98.6%, transparent 98.6%);
# }
# #T_37b01_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 78.6%, transparent 78.6%);
# }
# #T_37b01_row3_col5 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_37b01_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.5%, transparent 21.5%);
# }
# #T_37b01_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 27.6%, transparent 27.6%);
# }
# #T_37b01_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 33.0%, transparent 33.0%);
#   background-color: lightcoral;
# }
# #T_37b01_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 23.7%, transparent 23.7%);
# }
# #T_37b01_row4_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_37b01">
#   <caption>Sales Dashboard - Quarterly Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37b01_level0_col0" class="col_heading level0 col0" >Product</th>
#       <th id="T_37b01_level0_col1" class="col_heading level0 col1" >Q1_Sales</th>
#       <th id="T_37b01_level0_col2" class="col_heading level0 col2" >Q2_Sales</th>
#       <th id="T_37b01_level0_col3" class="col_heading level0 col3" >Q3_Sales</th>
#       <th id="T_37b01_level0_col4" class="col_heading level0 col4" >Q4_Sales</th>
#       <th id="T_37b01_level0_col5" class="col_heading level0 col5" >Total_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37b01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37b01_row0_col0" class="data row0 col0" >Product A</td>
#       <td id="T_37b01_row0_col1" class="data row0 col1" >$202</td>
#       <td id="T_37b01_row0_col2" class="data row0 col2" >$171</td>
#       <td id="T_37b01_row0_col3" class="data row0 col3" >$566</td>
#       <td id="T_37b01_row0_col4" class="data row0 col4" >$472</td>
#       <td id="T_37b01_row0_col5" class="data row0 col5" >$1,411</td>
#     </tr>
#     <tr>
#       <th id="T_37b01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37b01_row1_col0" class="data row1 col0" >Product B</td>
#       <td id="T_37b01_row1_col1" class="data row1 col1" >$535</td>
#       <td id="T_37b01_row1_col2" class="data row1 col2" >$800</td>
#       <td id="T_37b01_row1_col3" class="data row1 col3" >$314</td>
#       <td id="T_37b01_row1_col4" class="data row1 col4" >$199</td>
#       <td id="T_37b01_row1_col5" class="data row1 col5" >$1,848</td>
#     </tr>
#     <tr>
#       <th id="T_37b01_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37b01_row2_col0" class="data row2 col0" >Product C</td>
#       <td id="T_37b01_row2_col1" class="data row2 col1" >$960</td>
#       <td id="T_37b01_row2_col2" class="data row2 col2" >$120</td>
#       <td id="T_37b01_row2_col3" class="data row2 col3" >$430</td>
#       <td id="T_37b01_row2_col4" class="data row2 col4" >$971</td>
#       <td id="T_37b01_row2_col5" class="data row2 col5" >$2,481</td>
#     </tr>
#     <tr>
#       <th id="T_37b01_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_37b01_row3_col0" class="data row3 col0" >Product D</td>
#       <td id="T_37b01_row3_col1" class="data row3 col1" >$370</td>
#       <td id="T_37b01_row3_col2" class="data row3 col2" >$714</td>
#       <td id="T_37b01_row3_col3" class="data row3 col3" >$558</td>
#       <td id="T_37b01_row3_col4" class="data row3 col4" >$763</td>
#       <td id="T_37b01_row3_col5" class="data row3 col5" >$2,405</td>
#     </tr>
#     <tr>
#       <th id="T_37b01_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_37b01_row4_col0" class="data row4 col0" >Product E</td>
#       <td id="T_37b01_row4_col1" class="data row4 col1" >$206</td>
#       <td id="T_37b01_row4_col2" class="data row4 col2" >$221</td>
#       <td id="T_37b01_row4_col3" class="data row4 col3" >$187</td>
#       <td id="T_37b01_row4_col4" class="data row4 col4" >$230</td>
#       <td id="T_37b01_row4_col5" class="data row4 col5" >$844</td>
#     </tr>
#   </tbody>
# </table>
