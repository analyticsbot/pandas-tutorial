# %% [markdown]
# # Chapter 7: Grouping for Aggregation, Filtration and Transformation
# ## Recipes
# * [Defining an aggregation](#Defining-an-aggregation)
# * [Grouping and aggregating with multiple columns and functions](#Grouping-and-aggregating-with-multiple-columns-and-functions)
# * [Removing the MultiIndex after grouping](#Removing-the-MultiIndex-after-grouping)
# * [Customizing an aggregation function](#Customizing-an-aggregation-function)
# * [Customizing aggregating functions with \*args and \*\*kwargs](#Customizing-aggregating-functions-with-*args-and-**kwargs)
# * [Examining the groupby object](#Examining-a-groupby-object)
# * [Filtering for states with a minority majority](#Filtering-for-states-with-a-minority-majority)
# * [Transforming through a weight loss bet](#Transforming-through-a-weight-loss)
# * [Calculating weighted mean SAT scores per state with apply](#Calculating-weighted-mean-SAT-scores-per-state-with-apply)
# * [Grouping by continuous variables](#Grouping-by-continuous-variables)
# * [Counting the total number of flights between cities](#Counting-the-total-number-of-flights-between-cities)
# * [Finding the longest streak of on-time flights](#Finding-the-longest-streak-of-on-time-flights)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Defining an aggregation

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg('mean').head()
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %%
flights.groupby('AIRLINE').agg({'ARR_DELAY':'mean'}).head()
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg(np.mean).head()
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/16263011.py:1: FutureWarning: The provided callable <function mean at 0x134a67ba0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   flights.groupby('AIRLINE')['ARR_DELAY'].agg(np.mean).head()
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].mean().head()
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# ## How it works...

# %%
grouped = flights.groupby('AIRLINE')
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ## There's more

# %%
# Use transform for element-wise operations
flights.groupby('AIRLINE')['ARR_DELAY'].transform(np.sqrt)
# Out:
# /Users/neo/Downloads/Personal/Projects/pandas-tutorial/venv/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0        8.062258
# 1             NaN
# 2        5.916080
# 3             NaN
# 4        6.244998
#            ...
# 58487         NaN
# 58488    2.000000
# 58489         NaN
# 58490    5.830952
# 58491         NaN
# Name: ARR_DELAY, Length: 58492, dtype: float64

# %% [markdown]
# # Grouping and aggregating with multiple columns and functions

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
# The number of cancelled flights for every airline per day weekday
flights.groupby(['AIRLINE', 'WEEKDAY'])['CANCELLED'].agg('sum').head(7)
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#          6          21
#          7          29
# Name: CANCELLED, dtype: int64

# %%
#Find the number and percentage of cancelled and diverted flights for every airline per weekday
flights.groupby(['AIRLINE', 'WEEKDAY'])[['CANCELLED', 'DIVERTED']].agg(['sum', 'mean']).head(7)
# Out:
#                 CANCELLED           DIVERTED
#                       sum      mean      sum      mean
# AIRLINE WEEKDAY
# AA      1              41  0.032106        6  0.004699
#         2               9  0.007341        2  0.001631
#         3              16  0.011949        2  0.001494
#         4              20  0.015004        5  0.003751
#         5              18  0.014151        1  0.000786
#         6              21  0.018667        9  0.008000
#         7              29  0.021837        1  0.000753

# %%
# For each origin to destination flight, find the total number of flights, 
# the number and percentage of cancelled flights and the average and variance of the airtime. 
group_cols = ['ORG_AIR', 'DEST_AIR']
agg_dict = {'CANCELLED':['sum', 'mean', 'size'], 
            'AIR_TIME':['mean', 'var']}
flights.groupby(group_cols).agg(agg_dict).head()
# flights.groupby(['ORG_AIR', 'DEST_AIR']).agg({'CANCELLED': ['sum', 'mean', 'size'], 
#                                               'AIR_TIME':['mean', 'var']}).head()
# Out:
#                  CANCELLED              AIR_TIME
#                        sum mean size        mean        var
# ORG_AIR DEST_AIR
# ATL     ABE              0  0.0   31   96.387097  45.778495
#         ABQ              0  0.0   16  170.500000  87.866667
#         ABY              0  0.0   19   28.578947   6.590643
#         ACY              0  0.0    6   91.333333  11.466667
#         AEX              0  0.0   40   78.725000  47.332692

# %% [markdown]
# # Removing the MultiIndex after grouping

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
airline_info = flights.groupby(['AIRLINE', 'WEEKDAY'])\
                      .agg({'DIST':['sum', 'mean'], 
                                    'ARR_DELAY':['min', 'max']}).astype(int)
airline_info.head()
# Out:
#                     DIST       ARR_DELAY
#                      sum  mean       min  max
# AIRLINE WEEKDAY
# AA      1        1455386  1139       -60  551
#         2        1358256  1107       -52  725
#         3        1496665  1117       -45  473
#         4        1452394  1089       -46  349
#         5        1427749  1122       -41  732

# %%
level0 = airline_info.columns.get_level_values(0)
level0
# Out:
# Index(['DIST', 'DIST', 'ARR_DELAY', 'ARR_DELAY'], dtype='object')

# %%
level1 = airline_info.columns.get_level_values(1)
level1
# Out:
# Index(['sum', 'mean', 'min', 'max'], dtype='object')

# %%
airline_info.columns = level0 + '_' + level1

# %%
airline_info.head(7)
# Out:
#                  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# AIRLINE WEEKDAY
# AA      1         1455386       1139            -60            551
#         2         1358256       1107            -52            725
#         3         1496665       1117            -45            473
#         4         1452394       1089            -46            349
#         5         1427749       1122            -41            732
#         6         1265340       1124            -50            858
#         7         1461906       1100            -49            626

# %%
airline_info.reset_index().head(7)
# Out:
#   AIRLINE  WEEKDAY  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# 0      AA        1   1455386       1139            -60            551
# 1      AA        2   1358256       1107            -52            725
# 2      AA        3   1496665       1117            -45            473
# 3      AA        4   1452394       1089            -46            349
# 4      AA        5   1427749       1122            -41            732
# 5      AA        6   1265340       1124            -50            858
# 6      AA        7   1461906       1100            -49            626

# %% [markdown]
# ## There's more...

# %%
flights.groupby(['AIRLINE'], as_index=False)['DIST'].agg('mean').round(0)
# Out:
#    AIRLINE    DIST
# 0       AA  1114.0
# 1       AS  1066.0
# 2       B6  1772.0
# 3       DL   866.0
# 4       EV   460.0
# 5       F9   970.0
# 6       HA  2615.0
# 7       MQ   404.0
# 8       NK  1047.0
# 9       OO   511.0
# 10      UA  1231.0
# 11      US  1181.0
# 12      VX  1240.0
# 13      WN   810.0

# %%
flights.groupby(['AIRLINE'], as_index=False, sort=False)['DIST'].agg('mean')
# Out:
#    AIRLINE         DIST
# 0       WN   809.985626
# 1       UA  1230.918891
# 2       MQ   404.229041
# 3       AA  1114.347865
# 4       F9   969.593014
# 5       EV   460.237453
# 6       OO   511.239375
# 7       NK  1047.428100
# 8       US  1181.226625
# 9       AS  1065.884115
# 10      DL   866.448448
# 11      VX  1240.296073
# 12      B6  1771.882136
# 13      HA  2615.178571

# %% [markdown]
# # Customizing an aggregation function

# %%
college = pd.read_csv('../notebooks/data/college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]

# %%
college.groupby('STABBR')['UGDS'].agg(['mean', 'std']).round(0).head()
# Out:
#           mean      std
# STABBR
# AK      2493.0   4052.0
# AL      2790.0   4658.0
# AR      1644.0   3143.0
# AS      1276.0      NaN
# AZ      4130.0  14894.0

# %%
def max_deviation(s):
    std_score = (s - s.mean()) / s.std()
    return std_score.abs().max()

# %%
college.groupby('STABBR')['UGDS'].agg(max_deviation).round(1).head()
# Out:
# STABBR
# AK    2.6
# AL    5.8
# AR    6.3
# AS    NaN
# AZ    9.9
# Name: UGDS, dtype: float64

# %% [markdown]
# ## There's more...

# %%
college.groupby('STABBR')[['UGDS', 'SATVRMID', 'SATMTMID']].agg(max_deviation).round(1).head()
# Out:
#         UGDS  SATVRMID  SATMTMID
# STABBR
# AK       2.6       NaN       NaN
# AL       5.8       1.6       1.8
# AR       6.3       2.2       2.3
# AS       NaN       NaN       NaN
# AZ       9.9       1.9       1.4

# %%
college.groupby(['STABBR', 'RELAFFIL'])[['UGDS', 'SATVRMID', 'SATMTMID']].agg([max_deviation, 'mean', 'std']).round(1).head()
# Out:
#                          UGDS                      SATVRMID               \
#                 max_deviation    mean     std max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                  2.1  3508.9  4539.5           NaN    NaN   NaN
#        1                  1.1   123.3   132.9           NaN  555.0   NaN
# AL     0                  5.2  3248.8  5102.4           1.6  514.9  56.5
#        1                  2.4   979.7   870.8           1.5  498.0  53.0
# AR     0                  5.8  1793.7  3401.6           1.9  481.1  37.9
#
#                      SATMTMID
#                 max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                  NaN    NaN   NaN
#        1                  NaN  503.0   NaN
# AL     0                  1.7  515.8  56.7
#        1                  1.4  485.6  61.4
# AR     0                  2.0  503.6  39.0

# %%
max_deviation.__name__
# Out:
# 'max_deviation'

# %%
max_deviation.__name__ = 'Max Deviation'

# %%
# Fix the code by using a list instead of a tuple for column selection
college.groupby(['STABBR', 'RELAFFIL'])[['UGDS', 'SATVRMID', 'SATMTMID']]\
       .agg([max_deviation, 'mean', 'std']).round(1).head()
# Out:
#                          UGDS                      SATVRMID               \
#                 Max Deviation    mean     std Max Deviation   mean   std
# STABBR RELAFFIL
# AK     0                  2.1  3508.9  4539.5           NaN    NaN   NaN
#        1                  1.1   123.3   132.9           NaN  555.0   NaN
# AL     0                  5.2  3248.8  5102.4           1.6  514.9  56.5
#        1                  2.4   979.7   870.8           1.5  498.0  53.0
# AR     0                  5.8  1793.7  3401.6           1.9  481.1  37.9
#
#                      SATMTMID
#                 Max Deviation   mean   std
# STABBR RELAFFIL
# AK     0                  NaN    NaN   NaN
#        1                  NaN  503.0   NaN
# AL     0                  1.7  515.8  56.7
#        1                  1.4  485.6  61.4
# AR     0                  2.0  503.6  39.0

# %% [markdown]
# # Customizing aggregating functions with \*args and \*\*kwargs

# %%
college = pd.read_csv('../notebooks/data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])

# %%
import inspect
inspect.signature(grouped.agg)
# Out:
# <Signature (func=None, *args, engine=None, engine_kwargs=None, **kwargs)>

# %% [markdown]
# ## How to do it...

# %%
def pct_between_1_3k(s):
    return s.between(1000, 3000).mean()

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between_1_3k).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.142857
#         1           0.000000
# AL      0           0.236111
#         1           0.333333
# AR      0           0.279412
#         1           0.111111
# AS      0           1.000000
# AZ      0           0.096774
#         1           0.000000
# Name: UGDS, dtype: float64

# %%
def pct_between(s, low, high):
    return s.between(low, high).mean()

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, 10000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# ## How it works...

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, high=10000, low=1000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, high=10000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# ## There's more...

# %%
# Instead of:
# college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', pct_between], low=100, high=1000)

# Use a dictionary to specify which function gets which parameters:
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', 
                                                     ('pct_between', lambda x: pct_between(x, low=100, high=1000))])
# Out:
#                         mean  pct_between
# STABBR RELAFFIL
# AK     0         3508.857143     0.428571
#        1          123.333333     0.333333
# AL     0         3248.774648     0.333333
#        1          979.722222     0.250000
# AR     0         1793.691176     0.294118
# ...                      ...          ...
# WI     0         2879.130952     0.344828
#        1         1716.200000     0.240000
# WV     0         1873.857143     0.384615
#        1          716.428571     0.375000
# WY     0         2244.363636     0.090909
#
# [112 rows x 2 columns]

# %%
def make_agg_func(func, name, *args, **kwargs):
    def wrapper(x):
        return func(x, *args, **kwargs)
    wrapper.__name__ = name
    return wrapper

my_agg1 = make_agg_func(pct_between, 'pct_1_3k', low=1000, high=3000)
my_agg2 = make_agg_func(pct_between, 'pct_10_30k', 10000, 30000)

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', my_agg1, my_agg2]).head()
# Out:
#                         mean  pct_1_3k  pct_10_30k
# STABBR RELAFFIL
# AK     0         3508.857143  0.142857    0.142857
#        1          123.333333  0.000000    0.000000
# AL     0         3248.774648  0.236111    0.083333
#        1          979.722222  0.333333    0.000000
# AR     0         1793.691176  0.279412    0.014706

# %% [markdown]
# # Examining a groupby object

# %%
college = pd.read_csv('../notebooks/data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
print([attr for attr in dir(grouped) if not attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'ewm', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sample', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'value_counts', 'var']

# %%
grouped.ngroups
# Out:
# 112

# %%
groups = list(grouped.groups.keys())
groups[:6]
# Out:
# [('AK', 0), ('AK', 1), ('AL', 0), ('AL', 1), ('AR', 0), ('AR', 1)]

# %%
grouped.get_group(('FL', 1)).head()
# Out:
#                                     INSTNM           CITY STABBR  HBCU  \
# 712         The Baptist College of Florida     Graceville     FL   0.0
# 713                       Barry University          Miami     FL   0.0
# 714  Gooding Institute of Nurse Anesthesia    Panama City     FL   0.0
# 715             Bethune-Cookman University  Daytona Beach     FL   1.0
# 724             Johnson University Florida      Kissimmee     FL   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 712      0.0        0.0         1     545.0     465.0           0.0  ...
# 713      0.0        0.0         1     470.0     462.0           0.0  ...
# 714      0.0        0.0         1       NaN       NaN           0.0  ...
# 715      0.0        0.0         1     405.0     395.0           0.0  ...
# 724      0.0        0.0         1     480.0     470.0           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 712     0.0308    0.0000     0.0507    0.2291         1   0.5878    0.5602
# 713     0.0164    0.0741     0.0841    0.1518         1   0.5045    0.6733
# 714        NaN       NaN        NaN       NaN         0      NaN       NaN
# 715     0.0198    0.0205     0.0190    0.0523         1   0.7758    0.8867
# 724     0.0045    0.0045     0.0136    0.1636         1   0.6689    0.7384
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 712   0.3531            30800               20052
# 713   0.4361            44100               28250
# 714      NaN              NaN   PrivacySuppressed
# 715   0.0647            29400               36250
# 724   0.2185            26300               20199
#
# [5 rows x 27 columns]

# %%
from IPython.display import display

# %%
i = 0
for name, group in grouped:
    print(name)
    display(group.head(2))
    i += 1
    if i == 5:
        break
# Out:
# ('AK', np.int64(0))
#                             INSTNM       CITY STABBR  HBCU  MENONLY  \
# 60  University of Alaska Anchorage  Anchorage     AK   0.0      0.0
# 62  University of Alaska Fairbanks  Fairbanks     AK   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 60        0.0         0       NaN       NaN           0.0  ...     0.0980
# 62        0.0         0       NaN       NaN           0.0  ...     0.0401
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 60    0.0181     0.0457    0.4539         1   0.2385    0.2647   0.4386
# 62    0.0110     0.3060    0.3887         1   0.2263    0.2550   0.4519
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 60            42500             19449.5
# 62            36200               19355
#
# [2 rows x 27 columns]
# ('AK', np.int64(1))
#                        INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 61       Alaska Bible College     Palmer     AK   0.0      0.0        0.0
# 64  Alaska Pacific University  Anchorage     AK   0.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 61         1       NaN       NaN           0.0  ...     0.0370       0.0
# 64         1     555.0     503.0           0.0  ...     0.0945       0.0
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 61     0.0000    0.1481         1   0.3571    0.2857   0.4286
# 64     0.0873    0.3745         1   0.3152    0.5297   0.4910
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 61              NaN   PrivacySuppressed
# 64            47000               23250
#
# [2 rows x 27 columns]
# ('AL', np.int64(0))
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
#
# [2 rows x 27 columns]
# ('AL', np.int64(1))
#                          INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 2            Amridge University  Montgomery     AL   0.0      0.0        0.0
# 10  Birmingham Southern College  Birmingham     AL   0.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 2          1       NaN       NaN           1.0  ...     0.0000       0.0
# 10         1     560.0     560.0           0.0  ...     0.0051       0.0
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 2      0.2715    0.4536         1   0.6801    0.7795   0.8540
# 10     0.0051    0.0017         1   0.1920    0.4809   0.0152
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2             40100               23370
# 10            44200               27000
#
# [2 rows x 27 columns]
# ('AR', np.int64(0))
#                                           INSTNM         CITY STABBR  HBCU  \
# 128        University of Arkansas at Little Rock  Little Rock     AR   0.0
# 129  University of Arkansas for Medical Sciences  Little Rock     AR   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 128      0.0        0.0         0     470.0     510.0           0.0  ...
# 129      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 128     0.0755    0.0283     0.0003    0.4126         1   0.3941    0.4775
# 129     0.0281    0.0070     0.0169    0.2433         1   0.3944    0.6144
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 128   0.4062            33900               21736
# 129   0.5133            61400               12500
#
# [2 rows x 27 columns]

# %%
grouped.head(2).head(6)
# Out:
#                                  INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0              Alabama A & M University      Normal     AL   1.0      0.0
# 1   University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                    Amridge University  Montgomery     AL   0.0      0.0
# 10          Birmingham Southern College  Birmingham     AL   0.0      0.0
# 43           Prince Institute-Southeast    Elmhurst     IL   0.0      0.0
# 60       University of Alaska Anchorage   Anchorage     AK   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0         0.0         0     424.0     420.0           0.0  ...     0.0000
# 1         0.0         0     570.0     565.0           0.0  ...     0.0368
# 2         0.0         1       NaN       NaN           1.0  ...     0.0000
# 10        0.0         1     560.0     560.0           0.0  ...     0.0051
# 43        0.0         0       NaN       NaN           0.0  ...     0.0000
# 60        0.0         0       NaN       NaN           0.0  ...     0.0980
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0     0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1     0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2     0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 10    0.0000     0.0051    0.0017         1   0.1920    0.4809   0.0152
# 43    0.0000     0.0000    0.0000         1   0.7857    0.9375   0.6569
# 60    0.0181     0.0457    0.4539         1   0.2385    0.2647   0.4386
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0               30300               33888
# 1               39700             21941.5
# 2               40100               23370
# 10              44200               27000
# 43  PrivacySuppressed               20992
# 60              42500             19449.5
#
# [6 rows x 27 columns]

# %% [markdown]
# ## There's more...

# %%
grouped.nth([1, -1]).head(8)
# Out:
#                                           INSTNM         CITY STABBR  HBCU  \
# 1            University of Alabama at Birmingham   Birmingham     AL   0.0
# 10                   Birmingham Southern College   Birmingham     AL   0.0
# 62                University of Alaska Fairbanks    Fairbanks     AK   0.0
# 64                     Alaska Pacific University    Anchorage     AK   0.0
# 70          Empire Beauty School-Paradise Valley      Phoenix     AZ   0.0
# 71                   Empire Beauty School-Tucson       Tucson     AZ   0.0
# 129  University of Arkansas for Medical Sciences  Little Rock     AR   0.0
# 134                                 Lyon College   Batesville     AR   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 1        0.0        0.0         0     570.0     565.0           0.0  ...
# 10       0.0        0.0         1     560.0     560.0           0.0  ...
# 62       0.0        0.0         0       NaN       NaN           0.0  ...
# 64       0.0        0.0         1     555.0     503.0           0.0  ...
# 70       0.0        0.0         1       NaN       NaN           0.0  ...
# 71       0.0        0.0         0       NaN       NaN           0.0  ...
# 129      0.0        0.0         0       NaN       NaN           0.0  ...
# 134      0.0        0.0         1     505.0     528.0           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 1       0.0368    0.0179     0.0100    0.2607         1   0.3460    0.5214
# 10      0.0051    0.0000     0.0051    0.0017         1   0.1920    0.4809
# 62      0.0401    0.0110     0.3060    0.3887         1   0.2263    0.2550
# 64      0.0945    0.0000     0.0873    0.3745         1   0.3152    0.5297
# 70      0.0400    0.0000     0.0000    0.1600         0   0.6349    0.5873
# 71      0.0000    0.0000     0.0079    0.2222         1   0.7962    0.6615
# 129     0.0281    0.0070     0.0169    0.2433         1   0.3944    0.6144
# 134     0.0000    0.0333     0.0638    0.0101         1   0.4578    0.6740
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1     0.2422            39700             21941.5
# 10    0.0152            44200               27000
# 62    0.4519            36200               19355
# 64    0.4910            47000               23250
# 70    0.4651            17800                9588
# 71    0.4229            18200                9833
# 129   0.5133            61400               12500
# 134   0.0524            38600               25000
#
# [8 rows x 27 columns]

# %% [markdown]
# # Filtering for states with a minority majority

# %%
college = pd.read_csv('../notebooks/data/college.csv', index_col='INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# Out:
# 59

# %%
# %timeit college['STABBR'].nunique()
# Out:
# 131 μs ± 4.91 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE']
    total_minority = (df['UGDS'] * minority_pct).sum()
    total_ugds = df['UGDS'].sum()
    total_minority_pct = total_minority / total_ugds
    return total_minority_pct > threshold

# %%
college_filtered = grouped.filter(check_minority, threshold=.5)
college_filtered.head()
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Everest College-Phoenix                   Phoenix     AZ   0.0      0.0
# Collins College                           Phoenix     AZ   0.0      0.0
# Empire Beauty School-Paradise Valley      Phoenix     AZ   0.0      0.0
# Empire Beauty School-Tucson                Tucson     AZ   0.0      0.0
# Thunderbird School of Global Management  Glendale     AZ   0.0      0.0
#
#                                          WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Everest College-Phoenix                        0.0         1       NaN
# Collins College                                0.0         0       NaN
# Empire Beauty School-Paradise Valley           0.0         1       NaN
# Empire Beauty School-Tucson                    0.0         0       NaN
# Thunderbird School of Global Management        0.0         0       NaN
#
#                                          SATMTMID  DISTANCEONLY    UGDS  ...  \
# INSTNM                                                                   ...
# Everest College-Phoenix                       NaN           0.0  4102.0  ...
# Collins College                               NaN           0.0    83.0  ...
# Empire Beauty School-Paradise Valley          NaN           0.0    25.0  ...
# Empire Beauty School-Tucson                   NaN           0.0   126.0  ...
# Thunderbird School of Global Management       NaN           0.0     1.0  ...
#
#                                          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Everest College-Phoenix                     0.0373       0.0     0.1026
# Collins College                             0.0241       0.0     0.3855
# Empire Beauty School-Paradise Valley        0.0400       0.0     0.0000
# Empire Beauty School-Tucson                 0.0000       0.0     0.0079
# Thunderbird School of Global Management     0.0000       0.0     0.0000
#
#                                          PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Everest College-Phoenix                    0.4749         0   0.8291
# Collins College                            0.3373         0   0.7205
# Empire Beauty School-Paradise Valley       0.1600         0   0.6349
# Empire Beauty School-Tucson                0.2222         1   0.7962
# Thunderbird School of Global Management    1.0000         0   0.0000
#
#                                          PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Everest College-Phoenix                    0.7151   0.6700            28600
# Collins College                            0.8228   0.4764            25700
# Empire Beauty School-Paradise Valley       0.5873   0.4651            17800
# Empire Beauty School-Tucson                0.6615   0.4229            18200
# Thunderbird School of Global Management    0.0000   0.0000           118900
#
#                                          GRAD_DEBT_MDN_SUPP
# INSTNM
# Everest College-Phoenix                                9500
# Collins College                                       47000
# Empire Beauty School-Paradise Valley                   9588
# Empire Beauty School-Tucson                            9833
# Thunderbird School of Global Management   PrivacySuppressed
#
# [5 rows x 26 columns]

# %%
college.shape
# Out:
# (7535, 26)

# %%
college_filtered.shape
# Out:
# (3028, 26)

# %%
college_filtered['STABBR'].nunique()
# Out:
# 20

# %% [markdown]
# ## There's more...

# %%
college_filtered_20 = grouped.filter(check_minority, threshold=.2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %%
college_filtered_70 = grouped.filter(check_minority, threshold=.7)
college_filtered_70.shape
# Out:
# (957, 26)

# %%
college_filtered_70['STABBR'].nunique()
# Out:
# 10

# %%
college_filtered_95 = grouped.filter(check_minority, threshold=.95)
college_filtered_95.shape
# Out:
# (156, 26)

# %% [markdown]
# # Transforming through a weight-loss

# %%
weight_loss = pd.read_csv('../notebooks/data/weight_loss.csv')
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
def find_perc_loss(s):
    return (s - s.iloc[0]) / s.iloc[0]

# %%
bob_jan = weight_loss.query('Name=="Bob" and Month=="Jan"')
find_perc_loss(bob_jan['Weight'])
# Out:
# 0    0.000000
# 2   -0.010309
# 4   -0.027491
# 6   -0.027491
# Name: Weight, dtype: float64

# %%
pcnt_loss = weight_loss.groupby(['Name', 'Month'])['Weight'].transform(find_perc_loss)
pcnt_loss.head(8)
# Out:
# 0    0.000000
# 1    0.000000
# 2   -0.010309
# 3   -0.040609
# 4   -0.027491
# 5   -0.040609
# 6   -0.027491
# 7   -0.035533
# Name: Weight, dtype: float64

# %%
weight_loss['Perc Weight Loss'] = pcnt_loss.round(3)
weight_loss.query('Name=="Bob" and Month in ["Jan", "Feb"]')
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 0   Bob   Jan  Week 1     291             0.000
# 2   Bob   Jan  Week 2     288            -0.010
# 4   Bob   Jan  Week 3     283            -0.027
# 6   Bob   Jan  Week 4     283            -0.027
# 8   Bob   Feb  Week 1     283             0.000
# 10  Bob   Feb  Week 2     275            -0.028
# 12  Bob   Feb  Week 3     268            -0.053
# 14  Bob   Feb  Week 4     268            -0.053

# %%
week4 = weight_loss.query('Week == "Week 4"')
week4
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 6   Bob   Jan  Week 4     283            -0.027
# 7   Amy   Jan  Week 4     190            -0.036
# 14  Bob   Feb  Week 4     268            -0.053
# 15  Amy   Feb  Week 4     173            -0.089
# 22  Bob   Mar  Week 4     261            -0.026
# 23  Amy   Mar  Week 4     170            -0.017
# 30  Bob   Apr  Week 4     250            -0.042
# 31  Amy   Apr  Week 4     161            -0.053

# %%
winner = week4.pivot(index='Month', columns='Name', values='Perc Weight Loss')
winner
# Out:
# Name     Amy    Bob
# Month
# Apr   -0.053 -0.042
# Feb   -0.089 -0.053
# Jan   -0.036 -0.027
# Mar   -0.017 -0.026

# %%
# Alternative approach if you need to keep the original columns as strings
winner['Winner'] = np.where(pd.to_numeric(winner['Amy'], errors='coerce') < 
                           pd.to_numeric(winner['Bob'], errors='coerce'), 
                           'Amy', 'Bob')

# %%
# Apply highlight_min only to the numeric columns
winner.style.highlight_min(axis=1, subset=['Amy', 'Bob'])
# Out:
# <style type="text/css">
# #T_c8d77_row0_col0, #T_c8d77_row1_col0, #T_c8d77_row2_col0, #T_c8d77_row3_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c8d77">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th id="T_c8d77_level0_col0" class="col_heading level0 col0" >Amy</th>
#       <th id="T_c8d77_level0_col1" class="col_heading level0 col1" >Bob</th>
#       <th id="T_c8d77_level0_col2" class="col_heading level0 col2" >Winner</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8d77_level0_row0" class="row_heading level0 row0" >Apr</th>
#       <td id="T_c8d77_row0_col0" class="data row0 col0" >-0.053000</td>
#       <td id="T_c8d77_row0_col1" class="data row0 col1" >-0.042000</td>
#       <td id="T_c8d77_row0_col2" class="data row0 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_c8d77_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_c8d77_row1_col0" class="data row1 col0" >-0.089000</td>
#       <td id="T_c8d77_row1_col1" class="data row1 col1" >-0.053000</td>
#       <td id="T_c8d77_row1_col2" class="data row1 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_c8d77_level0_row2" class="row_heading level0 row2" >Jan</th>
#       <td id="T_c8d77_row2_col0" class="data row2 col0" >-0.036000</td>
#       <td id="T_c8d77_row2_col1" class="data row2 col1" >-0.027000</td>
#       <td id="T_c8d77_row2_col2" class="data row2 col2" >Amy</td>
#     </tr>
#     <tr>
#       <th id="T_c8d77_level0_row3" class="row_heading level0 row3" >Mar</th>
#       <td id="T_c8d77_row3_col0" class="data row3 col0" >-0.017000</td>
#       <td id="T_c8d77_row3_col1" class="data row3 col1" >-0.026000</td>
#       <td id="T_c8d77_row3_col2" class="data row3 col2" >Bob</td>
#     </tr>
#   </tbody>
# </table>

# %%
winner.Winner.value_counts()
# Out:
# Winner
# Amy    3
# Bob    1
# Name: count, dtype: int64

# %% [markdown]
# ## There's more...

# %%
week4a = week4.copy()
month_chron = week4a['Month'].unique() # or month.drop_duplicates
month_chron
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr'], dtype=object)

# %%
week4a['Month'] = pd.Categorical(week4a['Month'], 
                                 categories=month_chron,
                                 ordered=True)
week4a.pivot(index='Month', columns='Name', values='Perc Weight Loss')
# Out:
# Name     Amy    Bob
# Month
# Jan   -0.036 -0.027
# Feb   -0.089 -0.053
# Mar   -0.017 -0.026
# Apr   -0.053 -0.042

# %% [markdown]
# # Calculating weighted mean SAT scores per state with apply

# %%
college = pd.read_csv('../notebooks/data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# Out:
# (1184, 27)

# %%
college2.head(2)
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
#
# [2 rows x 27 columns]

# %%
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
college2.groupby('STABBR').apply(weighted_math_average).head()
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/2383084321.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').apply(weighted_math_average).head()
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
# dtype: int64

# %%
college2.columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
for name, group in college2.groupby('STABBR'):
    print(f"Checking group: {name}")
    print(group.head())  # Ensure 'UGDS' is in the group
    break  # Only print the first group
# Out:
# Checking group: AK
#                        INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 64  Alaska Pacific University  Anchorage     AK   0.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 64         1     555.0     503.0           0.0  ...     0.0945       0.0
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 64     0.0873    0.3745         1   0.3152    0.5297    0.491
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 64            47000               23250
#
# [1 rows x 27 columns]

# %%
college2.groupby('STABBR').apply(weighted_math_average).head()
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/4071226545.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').apply(weighted_math_average).head()
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
# dtype: int64

# %%
college2.groupby('STABBR').apply(weighted_math_average)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/2661896650.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').apply(weighted_math_average)
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
# CO    553
# CT    545
# DC    621
# DE    569
# FL    565
# GA    540
# HI    534
# IA    577
# ID    509
# IL    594
# IN    546
# KS    491
# KY    525
# LA    549
# MA    597
# MD    572
# ME    524
# MI    586
# MN    598
# MO    576
# MS    527
# MT    551
# NC    552
# ND    546
# NE    567
# NH    561
# NJ    554
# NM    529
# NV    516
# NY    578
# OH    569
# OK    557
# OR    540
# PA    553
# PR    571
# RI    567
# SC    549
# SD    528
# TN    544
# TX    548
# UT    577
# VA    550
# VI    390
# VT    566
# WA    555
# WI    593
# WV    500
# WY    540
# dtype: int64

# %%
from collections import OrderedDict
import pandas as pd

def weighted_average(df):
    data = OrderedDict()
    
    # Compute weighted averages
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']

    data['weighted_math_avg'] = weight_m.sum() / df['UGDS'].sum()
    data['weighted_verbal_avg'] = weight_v.sum() / df['UGDS'].sum()
    data['math_avg'] = df['SATMTMID'].mean()
    data['verbal_avg'] = df['SATVRMID'].mean()
    data['count'] = len(df)  # Count of schools in the group

    return pd.Series(data, dtype='float')  # ✅ Use float instead of int

# Apply the function
college2.groupby('STABBR').apply(weighted_average).head(10)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/2189526421.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').apply(weighted_average).head(10)
#         weighted_math_avg  weighted_verbal_avg    math_avg  verbal_avg  count
# STABBR
# AK             503.000000           555.000000  503.000000  555.000000    1.0
# AL             536.137917           533.383387  504.285714  508.476190   21.0
# AR             529.112332           504.876157  515.937500  491.875000   16.0
# AZ             569.313985           557.303350  536.666667  538.333333    6.0
# CA             564.945420           539.316605  562.902778  549.083333   72.0
# CO             553.123820           547.033996  540.214286  537.714286   14.0
# CT             545.341834           533.417563  522.500000  517.857143   14.0
# DC             621.905104           623.514036  588.333333  589.166667    6.0
# DE             569.954949           553.534560  495.000000  486.666667    3.0
# FL             565.324731           565.815873  521.842105  529.289474   38.0

# %%
from collections import OrderedDict
import pandas as pd

def weighted_average(df):
    data = OrderedDict()
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']

    wm_avg = weight_m.sum() / df['UGDS'].sum()
    wv_avg = weight_v.sum() / df['UGDS'].sum()

    data['weighted_math_avg'] = wm_avg
    data['weighted_verbal_avg'] = wv_avg
    data['math_avg'] = df['SATMTMID'].mean()
    data['verbal_avg'] = df['SATVRMID'].mean()
    data['count'] = len(df)

    return pd.Series(data)  # Let Pandas infer the correct dtype

college2.groupby('STABBR').apply(weighted_average).head(10)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/1323597703.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').apply(weighted_average).head(10)
#         weighted_math_avg  weighted_verbal_avg    math_avg  verbal_avg  count
# STABBR
# AK             503.000000           555.000000  503.000000  555.000000    1.0
# AL             536.137917           533.383387  504.285714  508.476190   21.0
# AR             529.112332           504.876157  515.937500  491.875000   16.0
# AZ             569.313985           557.303350  536.666667  538.333333    6.0
# CA             564.945420           539.316605  562.902778  549.083333   72.0
# CO             553.123820           547.033996  540.214286  537.714286   14.0
# CT             545.341834           533.417563  522.500000  517.857143   14.0
# DC             621.905104           623.514036  588.333333  589.166667    6.0
# DE             569.954949           553.534560  495.000000  486.666667    3.0
# FL             565.324731           565.815873  521.842105  529.289474   38.0

# %% [markdown]
# ## There's more...

# %%
from scipy.stats import gmean, hmean
def calculate_means(df):
    df_means = pd.DataFrame(index=['Arithmetic', 'Weighted', 'Geometric', 'Harmonic'])
    cols = ['SATMTMID', 'SATVRMID']
    for col in cols:
        arithmetic = df[col].mean()
        weighted = np.average(df[col], weights=df['UGDS'])
        geometric = gmean(df[col])
        harmonic = hmean(df[col])
        df_means[col] = [arithmetic, weighted, geometric, harmonic]
        
    df_means['count'] = len(df)
    return df_means.astype(int)

college2.groupby('STABBR').filter(lambda x: len(x) != 1).groupby('STABBR').apply(calculate_means).head(10)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/3719571720.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   college2.groupby('STABBR').filter(lambda x: len(x) != 1).groupby('STABBR').apply(calculate_means).head(10)
#                    SATMTMID  SATVRMID  count
# STABBR
# AL     Arithmetic       504       508     21
#        Weighted         536       533     21
#        Geometric        500       505     21
#        Harmonic         497       502     21
# AR     Arithmetic       515       491     16
#        Weighted         529       504     16
#        Geometric        514       489     16
#        Harmonic         513       487     16
# AZ     Arithmetic       536       538      6
#        Weighted         569       557      6

# %% [markdown]
# # Grouping by continuous variables

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.DIST.hasnans
# Out:
# False

# %%
flights.dropna(subset=['DIST']).shape
# Out:
# (58492, 14)

# %%
bins = [-np.inf, 200, 500, 1000, 2000, np.inf]
cuts = pd.cut(flights['DIST'], bins=bins)
cuts.head()
# Out:
# 0     (500.0, 1000.0]
# 1    (1000.0, 2000.0]
# 2     (500.0, 1000.0]
# 3    (1000.0, 2000.0]
# 4    (1000.0, 2000.0]
# Name: DIST, dtype: category
# Categories (5, interval[float64, right]): [(-inf, 200.0] < (200.0, 500.0] < (500.0, 1000.0] < (1000.0, 2000.0] < (2000.0, inf]]

# %%
cuts.value_counts()
# Out:
# DIST
# (500.0, 1000.0]     20659
# (200.0, 500.0]      15874
# (1000.0, 2000.0]    14186
# (2000.0, inf]        4054
# (-inf, 200.0]        3719
# Name: count, dtype: int64

# %%
flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True).round(3).head(15)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/1498986617.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True).round(3).head(15)
# DIST            AIRLINE
# (-inf, 200.0]   OO         0.326
#                 EV         0.289
#                 MQ         0.211
#                 DL         0.086
#                 AA         0.052
#                 UA         0.027
#                 WN         0.009
#                 AS         0.000
#                 B6         0.000
#                 F9         0.000
#                 HA         0.000
#                 NK         0.000
#                 US         0.000
#                 VX         0.000
# (200.0, 500.0]  WN         0.194
# Name: proportion, dtype: float64

# %% [markdown]
# ## How it works...

# %%
flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/414481562.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True)
# DIST           AIRLINE
# (-inf, 200.0]  OO         0.325625
#                EV         0.289325
#                MQ         0.210809
#                DL         0.086045
#                AA         0.052165
#                             ...
# (2000.0, inf]  AS         0.011593
#                F9         0.003700
#                EV         0.000000
#                MQ         0.000000
#                OO         0.000000
# Name: proportion, Length: 70, dtype: float64

# %% [markdown]
# ## There's more...

# %%
flights.groupby(cuts)['AIR_TIME'].quantile(q=[.25, .5, .75]).div(60).round(2)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/2062130766.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(cuts)['AIR_TIME'].quantile(q=[.25, .5, .75]).div(60).round(2)
# DIST
# (-inf, 200.0]     0.25    0.43
#                   0.50    0.50
#                   0.75    0.57
# (200.0, 500.0]    0.25    0.77
#                   0.50    0.92
#                   0.75    1.05
# (500.0, 1000.0]   0.25    1.43
#                   0.50    1.65
#                   0.75    1.92
# (1000.0, 2000.0]  0.25    2.50
#                   0.50    2.93
#                   0.75    3.40
# (2000.0, inf]     0.25    4.30
#                   0.50    4.70
#                   0.75    5.03
# Name: AIR_TIME, dtype: float64

# %%
labels=['Under an Hour', '1 Hour', '1-2 Hours', '2-4 Hours', '4+ Hours']
cuts2 = pd.cut(flights['DIST'], bins=bins, labels=labels)
flights.groupby(cuts2)['AIRLINE'].value_counts(normalize=True).round(3).unstack().style.highlight_max(axis=1)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/4001547007.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(cuts2)['AIRLINE'].value_counts(normalize=True).round(3).unstack().style.highlight_max(axis=1)
# <style type="text/css">
# #T_0b734_row0_col9, #T_0b734_row1_col13, #T_0b734_row2_col3, #T_0b734_row3_col0, #T_0b734_row4_col10 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0b734">
#   <thead>
#     <tr>
#       <th class="index_name level0" >AIRLINE</th>
#       <th id="T_0b734_level0_col0" class="col_heading level0 col0" >AA</th>
#       <th id="T_0b734_level0_col1" class="col_heading level0 col1" >AS</th>
#       <th id="T_0b734_level0_col2" class="col_heading level0 col2" >B6</th>
#       <th id="T_0b734_level0_col3" class="col_heading level0 col3" >DL</th>
#       <th id="T_0b734_level0_col4" class="col_heading level0 col4" >EV</th>
#       <th id="T_0b734_level0_col5" class="col_heading level0 col5" >F9</th>
#       <th id="T_0b734_level0_col6" class="col_heading level0 col6" >HA</th>
#       <th id="T_0b734_level0_col7" class="col_heading level0 col7" >MQ</th>
#       <th id="T_0b734_level0_col8" class="col_heading level0 col8" >NK</th>
#       <th id="T_0b734_level0_col9" class="col_heading level0 col9" >OO</th>
#       <th id="T_0b734_level0_col10" class="col_heading level0 col10" >UA</th>
#       <th id="T_0b734_level0_col11" class="col_heading level0 col11" >US</th>
#       <th id="T_0b734_level0_col12" class="col_heading level0 col12" >VX</th>
#       <th id="T_0b734_level0_col13" class="col_heading level0 col13" >WN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DIST</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b734_level0_row0" class="row_heading level0 row0" >Under an Hour</th>
#       <td id="T_0b734_row0_col0" class="data row0 col0" >0.052000</td>
#       <td id="T_0b734_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0b734_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_0b734_row0_col3" class="data row0 col3" >0.086000</td>
#       <td id="T_0b734_row0_col4" class="data row0 col4" >0.289000</td>
#       <td id="T_0b734_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_0b734_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_0b734_row0_col7" class="data row0 col7" >0.211000</td>
#       <td id="T_0b734_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_0b734_row0_col9" class="data row0 col9" >0.326000</td>
#       <td id="T_0b734_row0_col10" class="data row0 col10" >0.027000</td>
#       <td id="T_0b734_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_0b734_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_0b734_row0_col13" class="data row0 col13" >0.009000</td>
#     </tr>
#     <tr>
#       <th id="T_0b734_level0_row1" class="row_heading level0 row1" >1 Hour</th>
#       <td id="T_0b734_row1_col0" class="data row1 col0" >0.071000</td>
#       <td id="T_0b734_row1_col1" class="data row1 col1" >0.001000</td>
#       <td id="T_0b734_row1_col2" class="data row1 col2" >0.007000</td>
#       <td id="T_0b734_row1_col3" class="data row1 col3" >0.189000</td>
#       <td id="T_0b734_row1_col4" class="data row1 col4" >0.156000</td>
#       <td id="T_0b734_row1_col5" class="data row1 col5" >0.005000</td>
#       <td id="T_0b734_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_0b734_row1_col7" class="data row1 col7" >0.100000</td>
#       <td id="T_0b734_row1_col8" class="data row1 col8" >0.012000</td>
#       <td id="T_0b734_row1_col9" class="data row1 col9" >0.159000</td>
#       <td id="T_0b734_row1_col10" class="data row1 col10" >0.062000</td>
#       <td id="T_0b734_row1_col11" class="data row1 col11" >0.016000</td>
#       <td id="T_0b734_row1_col12" class="data row1 col12" >0.028000</td>
#       <td id="T_0b734_row1_col13" class="data row1 col13" >0.194000</td>
#     </tr>
#     <tr>
#       <th id="T_0b734_level0_row2" class="row_heading level0 row2" >1-2 Hours</th>
#       <td id="T_0b734_row2_col0" class="data row2 col0" >0.144000</td>
#       <td id="T_0b734_row2_col1" class="data row2 col1" >0.023000</td>
#       <td id="T_0b734_row2_col2" class="data row2 col2" >0.003000</td>
#       <td id="T_0b734_row2_col3" class="data row2 col3" >0.206000</td>
#       <td id="T_0b734_row2_col4" class="data row2 col4" >0.101000</td>
#       <td id="T_0b734_row2_col5" class="data row2 col5" >0.038000</td>
#       <td id="T_0b734_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_0b734_row2_col7" class="data row2 col7" >0.051000</td>
#       <td id="T_0b734_row2_col8" class="data row2 col8" >0.030000</td>
#       <td id="T_0b734_row2_col9" class="data row2 col9" >0.106000</td>
#       <td id="T_0b734_row2_col10" class="data row2 col10" >0.131000</td>
#       <td id="T_0b734_row2_col11" class="data row2 col11" >0.025000</td>
#       <td id="T_0b734_row2_col12" class="data row2 col12" >0.004000</td>
#       <td id="T_0b734_row2_col13" class="data row2 col13" >0.138000</td>
#     </tr>
#     <tr>
#       <th id="T_0b734_level0_row3" class="row_heading level0 row3" >2-4 Hours</th>
#       <td id="T_0b734_row3_col0" class="data row3 col0" >0.264000</td>
#       <td id="T_0b734_row3_col1" class="data row3 col1" >0.016000</td>
#       <td id="T_0b734_row3_col2" class="data row3 col2" >0.003000</td>
#       <td id="T_0b734_row3_col3" class="data row3 col3" >0.165000</td>
#       <td id="T_0b734_row3_col4" class="data row3 col4" >0.016000</td>
#       <td id="T_0b734_row3_col5" class="data row3 col5" >0.031000</td>
#       <td id="T_0b734_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_0b734_row3_col7" class="data row3 col7" >0.003000</td>
#       <td id="T_0b734_row3_col8" class="data row3 col8" >0.045000</td>
#       <td id="T_0b734_row3_col9" class="data row3 col9" >0.046000</td>
#       <td id="T_0b734_row3_col10" class="data row3 col10" >0.199000</td>
#       <td id="T_0b734_row3_col11" class="data row3 col11" >0.040000</td>
#       <td id="T_0b734_row3_col12" class="data row3 col12" >0.012000</td>
#       <td id="T_0b734_row3_col13" class="data row3 col13" >0.160000</td>
#     </tr>
#     <tr>
#       <th id="T_0b734_level0_row4" class="row_heading level0 row4" >4+ Hours</th>
#       <td id="T_0b734_row4_col0" class="data row4 col0" >0.212000</td>
#       <td id="T_0b734_row4_col1" class="data row4 col1" >0.012000</td>
#       <td id="T_0b734_row4_col2" class="data row4 col2" >0.080000</td>
#       <td id="T_0b734_row4_col3" class="data row4 col3" >0.171000</td>
#       <td id="T_0b734_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0b734_row4_col5" class="data row4 col5" >0.004000</td>
#       <td id="T_0b734_row4_col6" class="data row4 col6" >0.028000</td>
#       <td id="T_0b734_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="T_0b734_row4_col8" class="data row4 col8" >0.019000</td>
#       <td id="T_0b734_row4_col9" class="data row4 col9" >0.000000</td>
#       <td id="T_0b734_row4_col10" class="data row4 col10" >0.289000</td>
#       <td id="T_0b734_row4_col11" class="data row4 col11" >0.065000</td>
#       <td id="T_0b734_row4_col12" class="data row4 col12" >0.074000</td>
#       <td id="T_0b734_row4_col13" class="data row4 col13" >0.046000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Counting the total number of flights between cities

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights_ct = flights.groupby(['ORG_AIR', 'DEST_AIR']).size()
flights_ct.head()
# Out:
# ORG_AIR  DEST_AIR
# ATL      ABE         31
#          ABQ         16
#          ABY         19
#          ACY          6
#          AEX         40
# dtype: int64

# %%
flights_ct.loc[[('ATL', 'IAH'), ('IAH', 'ATL')]]
# Out:
# ORG_AIR  DEST_AIR
# ATL      IAH         121
# IAH      ATL         148
# dtype: int64

# %%
flights_sort = flights[['ORG_AIR', 'DEST_AIR']].apply(sorted, axis=1)
flights_sort.head()
# Out:
# 0    [LAX, SLC]
# 1    [DEN, IAD]
# 2    [DFW, VPS]
# 3    [DCA, DFW]
# 4    [LAX, MCI]
# dtype: object

# %%
# First, create a DataFrame with sorted values
flights_sort = flights[['ORG_AIR', 'DEST_AIR']].apply(sorted, axis=1)

# Convert the Series to a DataFrame and name the columns
flights_sort = pd.DataFrame(flights_sort.tolist(), columns=['AIR1', 'AIR2'])

# Now you can group by the columns
flights_ct2 = flights_sort.groupby(['AIR1', 'AIR2']).size()
flights_ct2.head()
# Out:
# AIR1  AIR2
# ABE   ATL     31
#       ORD     24
# ABI   DFW     74
# ABQ   ATL     16
#       DEN     46
# dtype: int64

# %%
flights_ct2.loc[('ATL', 'IAH')]
# Out:
# np.int64(269)

# %% [markdown]
# ## There's more...

# %%
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
data_sorted[:10]
# Out:
# array([['LAX', 'SLC'],
#        ['DEN', 'IAD'],
#        ['DFW', 'VPS'],
#        ['DCA', 'DFW'],
#        ['LAX', 'MCI'],
#        ['IAH', 'SAN'],
#        ['DFW', 'MSY'],
#        ['PHX', 'SFO'],
#        ['ORD', 'STL'],
#        ['IAH', 'SJC']], dtype=object)

# %%
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
fs_orig = flights_sort.rename({'ORG_AIR':'AIR1', 'DEST_AIR':'AIR2'})
flights_sort2.equals(fs_orig)
# Out:
# True

# %%
# %timeit flights_sort = flights[['ORG_AIR', 'DEST_AIR']].apply(sorted, axis=1)
# Out:
# 88.1 ms ± 1.34 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
# Out:
# 3.58 ms ± 325 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Finding the longest streak of on-time flights

# %%
s = pd.Series([1, 1, 1, 0, 1, 1, 1, 0])
s
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    1
# 7    0
# dtype: int64

# %%
s1 = s.cumsum()
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# 5    5
# 6    6
# 7    6
# dtype: int64

# %%
s.mul(s1).diff()
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3   -3.0
# 4    4.0
# 5    1.0
# 6    1.0
# 7   -6.0
# dtype: float64

# %%
s.mul(s1).diff().where(lambda x: x < 0)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -3.0
# 4    NaN
# 5    NaN
# 6    NaN
# 7   -6.0
# dtype: float64

# %%
s.mul(s1).diff().where(lambda x: x < 0).ffill().add(s1, fill_value=0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    1.0
# 5    2.0
# 6    3.0
# 7    0.0
# dtype: float64

# %%
flights = pd.read_csv('../notebooks/data/flights.csv')
flights['ON_TIME'] = flights['ARR_DELAY'].lt(15).astype(int)
flights[['AIRLINE', 'ORG_AIR', 'ON_TIME']].head(10)
# Out:
#   AIRLINE ORG_AIR  ON_TIME
# 0      WN     LAX        0
# 1      UA     DEN        1
# 2      MQ     DFW        0
# 3      AA     DFW        1
# 4      WN     LAX        0
# 5      UA     IAH        1
# 6      AA     DFW        0
# 7      F9     SFO        1
# 8      AA     ORD        1
# 9      UA     IAH        1

# %%
def max_streak(s):
    s1 = s.cumsum()
    return s.mul(s1).diff().where(lambda x: x < 0) \
            .ffill().add(s1, fill_value=0).max()

# %%
flights.sort_values(['MONTH', 'DAY', 'SCHED_DEP']) \
       .groupby(['AIRLINE', 'ORG_AIR'])['ON_TIME'] \
       .agg(['mean', 'size', max_streak]).round(2).head()
# Out:
#                  mean  size  max_streak
# AIRLINE ORG_AIR
# AA      ATL      0.82   233        15.0
#         DEN      0.74   219        17.0
#         DFW      0.78  4006        64.0
#         IAH      0.80   196        24.0
#         LAS      0.79   374        29.0

# %% [markdown]
# ## There's more...

# %%
import pandas as pd

def max_delay_streak(df):
    df = df.reset_index(drop=True)

    # Ensure ON_TIME is binary (0 or 1)
    s = 1 - df['ON_TIME'].fillna(0).astype(int)  # Convert to integer 0/1
    s1 = s.cumsum()

    # Compute streak length
    streak = s.mul(s1).diff().where(lambda x: x < 0).ffill().add(s1, fill_value=0)

    if streak.max() == 0:  # If no delay streak exists
        return pd.DataFrame(columns=['MONTH', 'DAY', 'streak'])

    # Identify start and end indices of max streak
    last_idx = streak.idxmax()
    first_idx = last_idx - int(streak.max()) + 1

    df_return = df.loc[[first_idx, last_idx], ['MONTH', 'DAY']].copy()
    df_return['streak'] = int(streak.max())  # Convert streak to int for safety
    df_return.index = ['first', 'last']
    df_return.index.name = 'streak_row'

    return df_return

# %%
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED  ON_TIME
# 0      94.0   590       1905       65.0         0          0        0
# 1     154.0  1452       1333      -13.0         0          0        1
# 2      85.0   641       1453       35.0         0          0        0
# 3     126.0  1192       1935       -7.0         0          0        1
# 4     166.0  1363       2225       39.0         0          0        0

# %%
# Apply function
flights.sort_values(['MONTH', 'DAY', 'SCHED_DEP']) \
       .groupby(['AIRLINE', 'ORG_AIR']) \
       .apply(max_delay_streak) \
       .sort_values(['streak', 'MONTH', 'DAY'], ascending=[False, True, True]) \
       .head(10)
# Out:
# /var/folders/7y/fzwln1_93mn3js3wyk61_6xm0000gn/T/ipykernel_86944/1775176215.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(max_delay_streak) \
#                       MONTH DAY streak
# AIRLINE ORG_AIR
# AA      DFW     first     2  26     38
#                 last      3   1     38
# MQ      ORD     first     1   6     28
#                 last      1  12     28
#         DFW     first     2  21     25
#                 last      2  26     25
# NK      ORD     first     6   7     15
#                 last      6  18     15
# DL      ATL     first    12  23     14
#                 last     12  24     14
